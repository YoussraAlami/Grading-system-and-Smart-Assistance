# %%
import pandas as pd
import os
import numpy as np
from keras import utils
from tensorflow.keras.callbacks import TensorBoard
from time import time
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
question7 = pd.read_csv('/kaggle/input/datasetar/Data/Question_7.csv', sep=',')
question7.head()
# Out:
#    ID                                           Question  \
# 0   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟
# 1   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟
# 2   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟
# 3   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟
# 4   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟
#
#                                              Réponse  Score
# 0          غزوة بدر الكبرى، في السنة الثانية للهجرة.      2
# 1     أول غزوة كانت بدر في السنة الثانية بعد الهجرة.      2
# 2          بدر الكبرى، والتي حدثت في السنة 2 للهجرة.      2
# 3                 كانت بدر، في السنة الثانية للهجرة.      2
# 4  الغزوة الأولى للمسلمين، بدر، حدثت في السنة الث...      2

# %%
question7.isnull().sum()
# Out:
# ID           0
# Question     0
# Réponse     10
# Score        0
# dtype: int64

# %%
rows_with_null_values = question7[question7['Réponse'].isnull()]

# Now you can display or inspect the rows
print(rows_with_null_values)
# Out:
#     ID                                           Question Réponse  Score
# 58   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0
# 61   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0
# 62   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0
# 63   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0
# 64   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0
# 66   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0
# 67   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0
# 88   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0
# 89   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0
# 90   7  ما هي أوَّل غزوة خاضها المسلمون؟ وفي أي عام وقعت؟     NaN      0

# %%
# Assuming your DataFrame is named 'question4'
question7.dropna(subset=['Réponse'], inplace=True)

# %%
question7['Réponse'].isna().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data = question7, x= 'Score')
plt.grid(True)
plt.show()

# %%
question7['Score'].unique()
# Out:
# array([2, 1, 0])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Assuming 'data' is your DataFrame and 'Score' is a column in your DataFrame
sns.set(style="darkgrid")

# Create the count plot
ax = sns.countplot(data=question7, x='Score')

# Calculate the percentage of each category
total = len(question1)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.1,
            f'{height/total:.1%}', ha="center")

# Format y-axis as percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))

plt.show()

# %%
question7.shape
# Out:
# (90, 4)

# %%
question7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        90 non-null     int64
#  1   Question  90 non-null     object
#  2   Réponse   90 non-null     object
#  3   Score     90 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 3.5+ KB

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with your dataset
# Replace 'your_column' with the actual column name you want to check for duplicates

# Check for duplicates based on all columns
duplicate_rows = question7[question7.duplicated()]

# Check for duplicates based on a specific column
duplicate_rows_specific_column = question6[question7.duplicated(subset=['Réponse'])]

# Get the number of duplicates
num_duplicates = len(duplicate_rows)
num_duplicates_specific_column = len(duplicate_rows_specific_column)

print(f"Total duplicates: {num_duplicates}")
print(f"Duplicates in 'Réponse': {num_duplicates_specific_column}")
# Out:
# Total duplicates: 27
# Duplicates in 'Réponse': 27

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install -U nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('arabic'))
#stop_words
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#data avant stopwrds removed
question7['Réponse']
# Out:
# 0             غزوة بدر الكبرى، في السنة الثانية للهجرة.
# 1        أول غزوة كانت بدر في السنة الثانية بعد الهجرة.
# 2             بدر الكبرى، والتي حدثت في السنة 2 للهجرة.
# 3                    كانت بدر، في السنة الثانية للهجرة.
# 4     الغزوة الأولى للمسلمين، بدر، حدثت في السنة الث...
#                             ...
# 95    بدر الكبرى، الغزوة الأولى للمسلمين، في السنة ا...
# 96         كان بدر الكبرى، في السنة الثانية بعد الهجرة.
# 97                 بدر، وقعت خلال السنة الثانية للهجرة.
# 98    الغزوة الأولى للمسلمين، بدر الكبرى، حدثت في ال...
# 99    بدر الكبرى، التي شهدت الانتصار الأول للمسلمين،...
# Name: Réponse, Length: 90, dtype: object

# %%
#Drop stop words
from nltk.stem.arlstem import ARLSTem
stemmmer = ARLSTem()

def remove_stowords(elements):
    corps = []
    for string in elements :
        string = nltk.sent_tokenize(string.strip())
        string = [ stemmmer.stem(word) for word in string if not word in stop_words ]
        string = ''.join(string)
        corps.append(string)
    return corps

# %%
corps7 = remove_stowords(question7['Réponse'])

# %%
#data after applying stopwords
corps7
# Out:
# ['غزوة بدر الكبري، في السنة الثانية للهجرة.',
#  'ول غزوة كانت بدر في السنة الثانية بعد الهجرة.',
#  'بدر الكبري، والتي حدثت في السنة 2 للهجرة.',
#  'كانت بدر، في السنة الثانية للهجرة.',
#  'غزوة الاولي للمسلمين، بدر، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، حدثت خلال السنة الثانية للهجرة.',
#  'غزوة بدر، التي وقعت خلال السنة الثانية للهجرة.',
#  'ول غزوة، بدر الكبري، حدثت في السنة الثانية للهجرة.',
#  'بدر، الغزوة الاولي للمسلمين، في السنة الثانية بعد الهجرة.',
#  'غزوة بدر الكبري، وقعت خلال السنة الثانية للهجرة.',
#  'بدر، الغزوة الاولي، حدثت في السنة الثانية للهجرة.',
#  'غزوة الاولي للمسلمين كانت بدر، في السنة الثانية بعد الهجرة.',
#  'بدر الكبري، التي شهدت الانتصار الاول للمسلمين، في السنة الثانية للهجرة.',
#  'غزوة الافتتاحية للمسلمين، بدر، وقعت في السنة الثانية للهجرة.',
#  'بدر الكبري، الغزوة الاولي، في السنة الثانية للهجرة.',
#  'لقاء الاول كان بدر الكبري، في السنة الثانية بعد الهجرة.',
#  'بدر، الغزوة الافتتاحية، وقعت خلال السنة الثانية للهجرة.',
#  'غزوة الاولي للمسلمين، بدر الكبري، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، التي شهدت الانتصار الاول للمسلمين، في السنة الثانية للهجرة.',
#  'غزوة بدر، اول غزوة للمسلمين، في السنة الثانية بعد الهجرة.',
#  'بدر، الغزوة الاولي للمسلمين، وقعت في السنة الثانية للهجرة.',
#  'غزوة الاولي، بدر الكبري، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، الغزوة الاولي، وقعت في السنة الثانية للهجرة.',
#  'غزوة الافتتاحية للمسلمين، بدر، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، الغزوة الاولي للمسلمين، في السنة الثانية للهجرة.',
#  'كان بدر الكبري، في السنة الثانية بعد الهجرة.',
#  'بدر، وقعت خلال السنة الثانية للهجرة.',
#  'غزوة الاولي للمسلمين، بدر الكبري، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، التي شهدت الانتصار الاول للمسلمين، في السنة الثانية للهجرة.',
#  'غزوة بدر، اول غزوة للمسلمين، في السنة الثانية بعد الهجرة.',
#  'بدر، الغزوة الاولي للمسلمين، وقعت في السنة الثانية للهجرة.',
#  'غزوة الاولي، بدر الكبري، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، الغزوة الاولي، وقعت في السنة الثانية للهجرة.',
#  'غزوة الافتتاحية للمسلمين، بدر، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، الغزوة الاولي للمسلمين، في السنة الثانية للهجرة.',
#  'بدر الكبري، في السنة الثاني',
#  'كان بدر الكبري',
#  'بدر',
#  'غزوة بدر الكبري',
#  '، وقعت خلال السنة الثانية للهجرة.',
#  'سنة الثانية للهجر',
#  '0',
#  'معركة بدر الصغري، في السنة 10 للهجرة.',
#  'في القدس في السنة 5 للهجرة.',
#  'بدر الكبري، في السنة 7 للهجرة.',
#  'معركة بدر الثانية، في السنة 3 للهجرة.',
#  'في السنة 4 للهجرة.',
#  'في السنة 9 للهجرة.',
#  'في السنة 6 للهجرة.',
#  'بدر الكبيرة، في السنة 8 للهجرة.',
#  'مكة المكرمة، في السنة 11 للهجرة.',
#  'بدر الصغري، في السنة 12 للهجرة.',
#  'في السنة 13 للهجرة.',
#  'في السنة 14 للهجرة.',
#  'بدر البيضاء، في السنة 15 للهجرة.',
#  'بدر في السنة 16 للهجرة.',
#  'في السنة 17 للهجرة.',
#  'بدر في السنة 18 للهجرة.',
#  'بدر القصيرة، في السنة 20 للهجرة.',
#  'بدر الحمراء، في السنة 21 للهجرة.',
#  'بدر المتوسطة، في السنة 3 للهجرة.',
#  'غزوة بدر الكبري',
#  'ول غزوة كانت بدر',
#  'بدر الكبري',
#  'كانت بدر، في السنة الثانية للهجرة.',
#  'غزوة الاولي للمسلمين، بدر، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، حدثت خلال السن',
#  'غزوة بدر السنة الثانية للهجرة.',
#  'بدر الكبري، حدثت في السنة الثانية للهجرة.',
#  'في السنة الثانية بعد الهجرة.',
#  'غزوة بدر الكبري، وقعت خلال السنة الثانية للهجرة.',
#  'بدر حدثت في السنة الثانية للهجرة.',
#  'بدر، في السنة الثانية بعد الهجرة.',
#  'في السنة الثانية للهجرة.',
#  'بدر، وقعت في السنة الثانية للهجرة.',
#  'غزوة، في السنة الثانية للهجرة.',
#  'غزوة، في السنة الثانية للهجرة.',
#  'غزوة، في السنة الثانية للهجرة.',
#  'غزوة، في السنة الثانية للهجرة.',
#  'غزوة، في السنة الثانية للهجرة.',
#  'غزوة، في السنة الثانية للهجرة.',
#  'بدر، الغزوة الاولي للمسلمين، وقعت في السنة الثانية للهجرة.',
#  'غزوة الاولي، بدر الكبري، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، الغزوة الاولي، وقعت في السنة الثانية للهجرة.',
#  'غزوة الافتتاحية للمسلمين، بدر، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، الغزوة الاولي للمسلمين، في السنة الثانية للهجرة.',
#  'كان بدر الكبري، في السنة الثانية بعد الهجرة.',
#  'بدر، وقعت خلال السنة الثانية للهجرة.',
#  'غزوة الاولي للمسلمين، بدر الكبري، حدثت في السنة الثانية للهجرة.',
#  'بدر الكبري، التي شهدت الانتصار الاول للمسلمين، في السنة الثانية للهجرة.']

# %%
# tokenization
from keras.preprocessing.text import Tokenizer,text_to_word_sequence , one_hot , text_to_word_sequence
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle




# Train tokenization
tokenizer = Tokenizer(filters=''''!"#$%&()+,-./:;<=>?@[\\]^{|}~\t\n÷×؛<>()&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ''''' )
#tokenizer = Tokenizer(filters='#' )

# Fit the tokenizer on the training texts
tokenizer.fit_on_texts(corps7)

with open('TokenizerModel7.pkl', 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(corps7)

# Pad sequences to ensure uniform length
max_sequence_length = max(len(s) for s in sequences)
sequences = pad_sequences(sequences, max_sequence_length)

# Get the word-to-index mapping
vocab_dict = tokenizer.word_index

# Calculate the vocabulary size
vocab_size = len(vocab_dict) + 1

#print(vocab_dict)

# %%
max_sequence_length
# Out:
# 11

# %%
vocab_size
# Out:
# 61

# %%
# !pip3 install gensim
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.3.0)

# %%
from gensim.models import KeyedVectors
fasttext_model = KeyedVectors.load_word2vec_format("/kaggle/input/fast-text-translation-data/fast_text_files/vectors/wiki.ar.vec")

# %%
# Word Embedding
from keras.layers import Embedding
import numpy as np

# Embedding Dimension
EMBEDDING_DIM = 300

# Total number of words in the vocabulary, including an index for unknown words
num_words = len(vocab_dict) + 1

# Counter for words not present in the FastText model
count = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

# Iterate through each word in the vocabulary
for word, idx in vocab_dict.items():
    # Check if the word is present in the FastText model
    if word in fasttext_model:
        # If yes, assign the FastText model's embedding vector to the word in the matrix
        embedding_matrix[idx] = fasttext_model.get_vector(word)
    else:
        # If the word is not present, increment the counter and print a message
        count += 1
        print("Word does not exist in the vocabulary ---> " + word)

       # Note: We could also assign a special embedding vector for unknown words.
        embedding_matrix[idx] = fasttext_model.get_vector("unk")
# Out:
# Word does not exist in the vocabulary ---> 3
# Word does not exist in the vocabulary ---> 2
# Word does not exist in the vocabulary ---> 0
# Word does not exist in the vocabulary ---> 10
# Word does not exist in the vocabulary ---> 5
# Word does not exist in the vocabulary ---> 7
# Word does not exist in the vocabulary ---> 4
# Word does not exist in the vocabulary ---> 9
# Word does not exist in the vocabulary ---> 6
# Word does not exist in the vocabulary ---> 8
# Word does not exist in the vocabulary ---> 11
# Word does not exist in the vocabulary ---> 12
# Word does not exist in the vocabulary ---> 13
# Word does not exist in the vocabulary ---> 14
# Word does not exist in the vocabulary ---> 15
# Word does not exist in the vocabulary ---> 16
# Word does not exist in the vocabulary ---> 17
# Word does not exist in the vocabulary ---> 18
# Word does not exist in the vocabulary ---> 20
# Word does not exist in the vocabulary ---> 21

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.20085999,  0.62853998, -0.043958  , ...,  0.080014  ,
#          0.36291999, -0.21774   ],
#        [-0.10685   , -0.062513  , -0.20926   , ...,  0.043603  ,
#          0.0070054 ,  0.097782  ],
#        ...,
#        [-0.25591001, -0.37051001, -0.51898998, ..., -0.25441   ,
#         -0.12774999,  0.2683    ],
#        [-0.016157  ,  0.13264   ,  0.14206   , ...,  0.35231   ,
#         -0.22701   ,  0.34606001],
#        [ 0.15386   ,  0.43533999, -0.53662002, ..., -0.44975001,
#         -0.095624  ,  0.1737    ]])

# %%
X = sequences

# %%
# X

# %%
Score = question7['Score']
y = tf.keras.utils.to_categorical(
    Score, num_classes=3, dtype='float32'
)

# %%
# y

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.regularizers import l2

input_dim=vocab_size
output_dim=33
input_length=max_sequence_length


# Define the LSTM model
model = Sequential()
model.add(Embedding(input_dim=input_dim, output_dim=output_dim, input_length=input_length))
model.add(LSTM(units=10,kernel_regularizer=l2(0.001)))
model.add(Dense(3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                    batch_size=64, epochs=80, verbose=1)



plt.figure(figsize=(16, 6))
# Courbe de perte
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Courbe de perte et de validation')
plt.xlabel('Époque')
plt.ylabel('Perte')
plt.legend()


# Courbe de précision
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Courbe de précision et de validation')
plt.xlabel('Époque')
plt.ylabel('Précision')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/80
# 2/2 [==============================] - 4s 683ms/step - loss: 1.1383 - accuracy: 0.2500 - val_loss: 1.1264 - val_accuracy: 0.6667
# Epoch 2/80
# 2/2 [==============================] - 0s 177ms/step - loss: 1.1286 - accuracy: 0.5000 - val_loss: 1.1179 - val_accuracy: 0.6667
# Epoch 3/80
# 2/2 [==============================] - 0s 200ms/step - loss: 1.1192 - accuracy: 0.6667 - val_loss: 1.1101 - val_accuracy: 0.6111
# Epoch 4/80
# 2/2 [==============================] - 0s 187ms/step - loss: 1.1113 - accuracy: 0.6111 - val_loss: 1.1021 - val_accuracy: 0.6111
# Epoch 5/80
# 2/2 [==============================] - 0s 41ms/step - loss: 1.1024 - accuracy: 0.5972 - val_loss: 1.0938 - val_accuracy: 0.6111
# Epoch 6/80
# 2/2 [==============================] - 0s 41ms/step - loss: 1.0941 - accuracy: 0.5972 - val_loss: 1.0849 - val_accuracy: 0.6111
# Epoch 7/80
# 2/2 [==============================] - 0s 40ms/step - loss: 1.0854 - accuracy: 0.5972 - val_loss: 1.0760 - val_accuracy: 0.6111
# Epoch 8/80
# 2/2 [==============================] - 0s 176ms/step - loss: 1.0759 - accuracy: 0.5972 - val_loss: 1.0671 - val_accuracy: 0.6111
# Epoch 9/80
# 2/2 [==============================] - 0s 172ms/step - loss: 1.0665 - accuracy: 0.5972 - val_loss: 1.0575 - val_accuracy: 0.6111
# Epoch 10/80
# 2/2 [==============================] - 0s 177ms/step - loss: 1.0570 - accuracy: 0.5972 - val_loss: 1.0472 - val_accuracy: 0.6111
# Epoch 11/80
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0466 - accuracy: 0.5972 - val_loss: 1.0364 - val_accuracy: 0.6111
# Epoch 12/80
# 2/2 [==============================] - 0s 167ms/step - loss: 1.0357 - accuracy: 0.5972 - val_loss: 1.0254 - val_accuracy: 0.6111
# Epoch 13/80
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0236 - accuracy: 0.5972 - val_loss: 1.0137 - val_accuracy: 0.6111
# Epoch 14/80
# 2/2 [==============================] - 0s 33ms/step - loss: 1.0116 - accuracy: 0.5972 - val_loss: 1.0009 - val_accuracy: 0.6111
# Epoch 15/80
# 2/2 [==============================] - 0s 182ms/step - loss: 0.9978 - accuracy: 0.6111 - val_loss: 0.9872 - val_accuracy: 0.6111
# Epoch 16/80
# 2/2 [==============================] - 0s 192ms/step - loss: 0.9834 - accuracy: 0.6111 - val_loss: 0.9724 - val_accuracy: 0.6111
# Epoch 17/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.9676 - accuracy: 0.6111 - val_loss: 0.9567 - val_accuracy: 0.6111
# Epoch 18/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.9512 - accuracy: 0.6111 - val_loss: 0.9403 - val_accuracy: 0.6111
# Epoch 19/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.9332 - accuracy: 0.6111 - val_loss: 0.9233 - val_accuracy: 0.6111
# Epoch 20/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9148 - accuracy: 0.6111 - val_loss: 0.9057 - val_accuracy: 0.6111
# Epoch 21/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.8959 - accuracy: 0.6250 - val_loss: 0.8880 - val_accuracy: 0.6111
# Epoch 22/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8765 - accuracy: 0.6250 - val_loss: 0.8706 - val_accuracy: 0.6111
# Epoch 23/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.8562 - accuracy: 0.6250 - val_loss: 0.8534 - val_accuracy: 0.6111
# Epoch 24/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8358 - accuracy: 0.6250 - val_loss: 0.8357 - val_accuracy: 0.6111
# Epoch 25/80
# 2/2 [==============================] - 0s 173ms/step - loss: 0.8158 - accuracy: 0.6389 - val_loss: 0.8177 - val_accuracy: 0.6111
# Epoch 26/80
# 2/2 [==============================] - 0s 182ms/step - loss: 0.7948 - accuracy: 0.6389 - val_loss: 0.7997 - val_accuracy: 0.6111
# Epoch 27/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7737 - accuracy: 0.6389 - val_loss: 0.7818 - val_accuracy: 0.6111
# Epoch 28/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7524 - accuracy: 0.6389 - val_loss: 0.7640 - val_accuracy: 0.6111
# Epoch 29/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7318 - accuracy: 0.6667 - val_loss: 0.7462 - val_accuracy: 0.6667
# Epoch 30/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7110 - accuracy: 0.6806 - val_loss: 0.7284 - val_accuracy: 0.6667
# Epoch 31/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6912 - accuracy: 0.6806 - val_loss: 0.7110 - val_accuracy: 0.6667
# Epoch 32/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6723 - accuracy: 0.6806 - val_loss: 0.6945 - val_accuracy: 0.6667
# Epoch 33/80
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6543 - accuracy: 0.6806 - val_loss: 0.6790 - val_accuracy: 0.6667
# Epoch 34/80
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6371 - accuracy: 0.6944 - val_loss: 0.6644 - val_accuracy: 0.6667
# Epoch 35/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6213 - accuracy: 0.7083 - val_loss: 0.6509 - val_accuracy: 0.6667
# Epoch 36/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6061 - accuracy: 0.7083 - val_loss: 0.6387 - val_accuracy: 0.6667
# Epoch 37/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5919 - accuracy: 0.7083 - val_loss: 0.6275 - val_accuracy: 0.7222
# Epoch 38/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5791 - accuracy: 0.7083 - val_loss: 0.6172 - val_accuracy: 0.7222
# Epoch 39/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5675 - accuracy: 0.7083 - val_loss: 0.6077 - val_accuracy: 0.8333
# Epoch 40/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5564 - accuracy: 0.7639 - val_loss: 0.5990 - val_accuracy: 0.8333
# Epoch 41/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5466 - accuracy: 0.7639 - val_loss: 0.5910 - val_accuracy: 0.8333
# Epoch 42/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5368 - accuracy: 0.7639 - val_loss: 0.5829 - val_accuracy: 0.8333
# Epoch 43/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5276 - accuracy: 0.7639 - val_loss: 0.5747 - val_accuracy: 0.8333
# Epoch 44/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5186 - accuracy: 0.7639 - val_loss: 0.5666 - val_accuracy: 0.8333
# Epoch 45/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5101 - accuracy: 0.7639 - val_loss: 0.5588 - val_accuracy: 0.8333
# Epoch 46/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5019 - accuracy: 0.7639 - val_loss: 0.5520 - val_accuracy: 0.8333
# Epoch 47/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4955 - accuracy: 0.7639 - val_loss: 0.5465 - val_accuracy: 0.8333
# Epoch 48/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4905 - accuracy: 0.7639 - val_loss: 0.5423 - val_accuracy: 0.8333
# Epoch 49/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4866 - accuracy: 0.7639 - val_loss: 0.5371 - val_accuracy: 0.8333
# Epoch 50/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4807 - accuracy: 0.7639 - val_loss: 0.5301 - val_accuracy: 0.8333
# Epoch 51/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4744 - accuracy: 0.7639 - val_loss: 0.5233 - val_accuracy: 0.8333
# Epoch 52/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4683 - accuracy: 0.7639 - val_loss: 0.5169 - val_accuracy: 0.8333
# Epoch 53/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4624 - accuracy: 0.7778 - val_loss: 0.5112 - val_accuracy: 0.8333
# Epoch 54/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4571 - accuracy: 0.7778 - val_loss: 0.5067 - val_accuracy: 0.8333
# Epoch 55/80
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4518 - accuracy: 0.7917 - val_loss: 0.5034 - val_accuracy: 0.8333
# Epoch 56/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4476 - accuracy: 0.7917 - val_loss: 0.5018 - val_accuracy: 0.8333
# Epoch 57/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4439 - accuracy: 0.7917 - val_loss: 0.5010 - val_accuracy: 0.8333
# Epoch 58/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4410 - accuracy: 0.7917 - val_loss: 0.4986 - val_accuracy: 0.8333
# Epoch 59/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4371 - accuracy: 0.8056 - val_loss: 0.4948 - val_accuracy: 0.8333
# Epoch 60/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4328 - accuracy: 0.8056 - val_loss: 0.4919 - val_accuracy: 0.8333
# Epoch 61/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4293 - accuracy: 0.8472 - val_loss: 0.4882 - val_accuracy: 0.8333
# Epoch 62/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4255 - accuracy: 0.8611 - val_loss: 0.4825 - val_accuracy: 0.8333
# Epoch 63/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4208 - accuracy: 0.8611 - val_loss: 0.4744 - val_accuracy: 0.8333
# Epoch 64/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4159 - accuracy: 0.8611 - val_loss: 0.4659 - val_accuracy: 0.8333
# Epoch 65/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4125 - accuracy: 0.8472 - val_loss: 0.4601 - val_accuracy: 0.8333
# Epoch 66/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4090 - accuracy: 0.8889 - val_loss: 0.4563 - val_accuracy: 0.8333
# Epoch 67/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4061 - accuracy: 0.9028 - val_loss: 0.4531 - val_accuracy: 0.8333
# Epoch 68/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4031 - accuracy: 0.9028 - val_loss: 0.4497 - val_accuracy: 0.8333
# Epoch 69/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3997 - accuracy: 0.9028 - val_loss: 0.4457 - val_accuracy: 0.8333
# Epoch 70/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3959 - accuracy: 0.9167 - val_loss: 0.4415 - val_accuracy: 0.8333
# Epoch 71/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3920 - accuracy: 0.9167 - val_loss: 0.4382 - val_accuracy: 0.8333
# Epoch 72/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3893 - accuracy: 0.9028 - val_loss: 0.4353 - val_accuracy: 0.8333
# Epoch 73/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3854 - accuracy: 0.9306 - val_loss: 0.4323 - val_accuracy: 0.8333
# Epoch 74/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3822 - accuracy: 0.9306 - val_loss: 0.4293 - val_accuracy: 0.8333
# Epoch 75/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3792 - accuracy: 0.9306 - val_loss: 0.4261 - val_accuracy: 0.8333
# Epoch 76/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3762 - accuracy: 0.9306 - val_loss: 0.4248 - val_accuracy: 0.8333
# Epoch 77/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3744 - accuracy: 0.9167 - val_loss: 0.4250 - val_accuracy: 0.8333
# Epoch 78/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3728 - accuracy: 0.9306 - val_loss: 0.4246 - val_accuracy: 0.8333
# Epoch 79/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3705 - accuracy: 0.9444 - val_loss: 0.4233 - val_accuracy: 0.8333
# Epoch 80/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3679 - accuracy: 0.9583 - val_loss: 0.4232 - val_accuracy: 0.8333

# %%
scores_trainig = model.evaluate(X_train, y_train, verbose=1)
print("Training Loss: %f%%" % (scores_trainig[0]))
print("Training Accuracy: %.2f%%" % (scores_trainig[1]*100))
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3657 - accuracy: 0.9722
# Training Loss: 0.365708%
# Training Accuracy: 97.22%

# %%
scores_test = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss: %f%%" % (scores_test[0]))
print("Test Accuracy: %.2f%%" % (scores_test[1]*100))
# Out:
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4232 - accuracy: 0.8333
# Test Loss: 0.423192%
# Test Accuracy: 83.33%

# %%
import numpy as np

def predict_sequence(model,response):
    
    response= remove_stowords(response)
    #print(corps)
# Convert texts to sequences of integers
    sequences = tokenizer.texts_to_sequences(response)

# Pad sequences to ensure uniform length

    sequences = pad_sequences(sequences, max_sequence_length)
   
    
    #print(sequences)
    # Reshape the input for model prediction
    #input_data = np.array([sequences])
    
    #print(input_data)
    # Make predictions
    predicted_probs = model.predict(sequences)
    predicted_value= np.argmax(predicted_probs, axis=1)
    
    #print(predicted_classes)
   
    return predicted_value[0]

# %%
test=[' بدر الكبرى']

# %%
predict_sequence(model,test)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1

# %%
from keras.models import load_model

# Assuming 'model' is your Keras model
model.save('model7.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
