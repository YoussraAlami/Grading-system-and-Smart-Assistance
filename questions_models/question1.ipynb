# %%
import pandas as pd
import os
import numpy as np
from keras import utils
from tensorflow.keras.callbacks import TensorBoard
from time import time
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
question1 = pd.read_csv('/kaggle/input/datasetar/Data/Question_1.csv', sep=',')
question1.head()
# Out:
#    ID                                           Question  \
# 0   1  ما أول هدية أهديت إلى الرسول صلى الله عليه وسل...
# 1   1  ما أول هدية أهديت إلى الرسول صلى الله عليه وسل...
# 2   1  ما أول هدية أهديت إلى الرسول صلى الله عليه وسل...
# 3   1  ما أول هدية أهديت إلى الرسول صلى الله عليه وسل...
# 4   1  ما أول هدية أهديت إلى الرسول صلى الله عليه وسل...
#
#                 Réponse  Score
# 0              قصعة خبز      1
# 1                   سمن      1
# 2                   لبن      1
# 3    زيد بن حارثة قدمها      0
# 4  هدية من زيد بن حارثة      0

# %%
question1['Score'].unique()
# Out:
# array([1, 0, 2])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data = question1, x= 'Score')
plt.grid(True)
plt.show()

# %%
question1.isnull().sum()
# Out:
# ID          0
# Question    0
# Réponse     0
# Score       0
# dtype: int64

# %%
rows_with_null_values = question1[question1['Réponse'].isnull()]

# Now you can display or inspect the rows
print(rows_with_null_values)
# Out:
# Empty DataFrame
# Columns: [ID, Question, Réponse, Score]
# Index: []

# %%
# Assuming your DataFrame is named 'question4'
#
question1.dropna(subset=['Réponse'], inplace=True)

# %%
question1['Réponse'].isna().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Assuming 'data' is your DataFrame and 'Score' is a column in your DataFrame
sns.set(style="darkgrid")

# Create the count plot
ax = sns.countplot(data=question1, x='Score')

# Calculate the percentage of each category
total = len(question1)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.1,
            f'{height/total:.1%}', ha="center")

# Format y-axis as percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))

plt.show()

# %%
question1.shape
# Out:
# (106, 4)

# %%
question1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        106 non-null    int64
#  1   Question  106 non-null    object
#  2   Réponse   106 non-null    object
#  3   Score     106 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.4+ KB

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with your dataset
# Replace 'your_column' with the actual column name you want to check for duplicates

# Check for duplicates based on all columns
duplicate_rows = question1[question1.duplicated()]

# Check for duplicates based on a specific column
duplicate_rows_specific_column = question1[question1.duplicated(subset=['Réponse'])]

# Get the number of duplicates
num_duplicates = len(duplicate_rows)
num_duplicates_specific_column = len(duplicate_rows_specific_column)

print(f"Total duplicates: {num_duplicates}")
print(f"Duplicates in 'Réponse': {num_duplicates_specific_column}")
# Out:
# Total duplicates: 49
# Duplicates in 'Réponse': 51

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install -U nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('arabic'))
#stop_words
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#data avant stopwrds removed
question1['Réponse']
# Out:
# 0                  قصعة خبز
# 1                       سمن
# 2                       لبن
# 3        زيد بن حارثة قدمها
# 4      هدية من زيد بن حارثة
#                ...
# 101                    هدية
# 102           قصعة من التمر
# 103          قصعة من الطعام
# 104                     فرس
# 105             أحد الزعماء
# Name: Réponse, Length: 106, dtype: object

# %%
#Drop stop words
from nltk.stem.arlstem import ARLSTem
stemmmer = ARLSTem()

def remove_stowords(elements):
    corps = []
    for string in elements :
        string = nltk.sent_tokenize(string.strip())
        string = [ stemmmer.stem(word) for word in string if not word in stop_words ]
        string = ''.join(string)
        corps.append(string)
    return corps

# %%
corps1 = remove_stowords(question1['Réponse'])

# %%
#data after applying stopwords
# corps10

# %%
# tokenization
from keras.preprocessing.text import Tokenizer,text_to_word_sequence , one_hot , text_to_word_sequence
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle




# Train tokenization
tokenizer = Tokenizer(filters=''''!"#$%&()+,-./:;<=>?@[\\]^{|}~\t\n÷×؛<>()&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ''''' )
#tokenizer = Tokenizer(filters='#' )

# Fit the tokenizer on the training texts
tokenizer.fit_on_texts(corps1)

with open('TokenizerModel1.pkl', 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(corps1)

# Pad sequences to ensure uniform length
max_sequence_length = max(len(s) for s in sequences)
sequences = pad_sequences(sequences, max_sequence_length)

# Get the word-to-index mapping
vocab_dict = tokenizer.word_index

# Calculate the vocabulary size
vocab_size = len(vocab_dict) + 1

#print(vocab_dict)

# %%
max_sequence_length
# Out:
# 10

# %%
# vocab_dict

# %%
# !pip3 install gensim
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.3.0)

# %%
from gensim.models import KeyedVectors
fasttext_model = KeyedVectors.load_word2vec_format("/kaggle/input/fast-text-translation-data/fast_text_files/vectors/wiki.ar.vec")

# %%
# Word Embedding
from keras.layers import Embedding
import numpy as np

# Embedding Dimension
EMBEDDING_DIM = 300

# Total number of words in the vocabulary, including an index for unknown words
num_words = len(vocab_dict) + 1

# Counter for words not present in the FastText model
count = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

# Iterate through each word in the vocabulary
for word, idx in vocab_dict.items():
    # Check if the word is present in the FastText model
    if word in fasttext_model:
        # If yes, assign the FastText model's embedding vector to the word in the matrix
        embedding_matrix[idx] = fasttext_model.get_vector(word)
    else:
        # If the word is not present, increment the counter and print a message
        count += 1
        print("Word does not exist in the vocabulary ---> " + word)

       # Note: We could also assign a special embedding vector for unknown words.
        embedding_matrix[idx] = fasttext_model.get_vector("unk")
# Out:
# Word does not exist in the vocabulary ---> هديت
# Word does not exist in the vocabulary ---> قدوما
# Word does not exist in the vocabulary ---> التجر
# Word does not exist in the vocabulary ---> الزعمء

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.38539001,  0.55699003,  0.14026   , ..., -0.36822   ,
#         -0.36752   ,  0.031194  ],
#        [-0.40231001, -0.35694   ,  0.095612  , ..., -0.20962   ,
#          0.33309999, -0.61219001],
#        ...,
#        [-0.15546   ,  0.34086999,  0.19058999, ..., -0.15808   ,
#          0.069228  ,  0.22154   ],
#        [-0.18708999, -0.12383   , -0.11015   , ..., -0.34556001,
#         -0.019726  ,  0.28031999],
#        [-0.25591001, -0.37051001, -0.51898998, ..., -0.25441   ,
#         -0.12774999,  0.2683    ]])

# %%
X = sequences

# %%
# X

# %%
Score = question1['Score']
y = tf.keras.utils.to_categorical(
    Score, num_classes=3, dtype='float32'
)

# %%
# y

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y_test.shape
# Out:
# (22, 3)

# %%
# from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.regularizers import l2
from tensorflow.keras.regularizers import l1
from keras.layers import Dropout

input_dim=vocab_size
output_dim=33
input_length=max_sequence_length


# Define the LSTM model
model = Sequential()
model.add(Embedding(input_dim=input_dim, output_dim=output_dim, input_length=input_length))
model.add(LSTM(units=10,kernel_regularizer=l2(0.0001)))
model.add(Dense(3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                    batch_size=64, epochs=80, verbose=1)



plt.figure(figsize=(16, 6))
# Courbe de perte
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Courbe de perte et de validation')
plt.xlabel('Époque')
plt.ylabel('Perte')
plt.legend()


# Courbe de précision
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Courbe de précision et de validation')
plt.xlabel('Époque')
plt.ylabel('Précision')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/80
# 2/2 [==============================] - 3s 641ms/step - loss: 1.1044 - accuracy: 0.2024 - val_loss: 1.0947 - val_accuracy: 0.6818
# Epoch 2/80
# 2/2 [==============================] - 0s 167ms/step - loss: 1.0944 - accuracy: 0.6667 - val_loss: 1.0910 - val_accuracy: 0.5455
# Epoch 3/80
# 2/2 [==============================] - 0s 167ms/step - loss: 1.0852 - accuracy: 0.7619 - val_loss: 1.0875 - val_accuracy: 0.5455
# Epoch 4/80
# 2/2 [==============================] - 0s 163ms/step - loss: 1.0760 - accuracy: 0.7262 - val_loss: 1.0842 - val_accuracy: 0.5455
# Epoch 5/80
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0662 - accuracy: 0.6786 - val_loss: 1.0808 - val_accuracy: 0.5455
# Epoch 6/80
# 2/2 [==============================] - 0s 163ms/step - loss: 1.0567 - accuracy: 0.6310 - val_loss: 1.0775 - val_accuracy: 0.5455
# Epoch 7/80
# 2/2 [==============================] - 0s 163ms/step - loss: 1.0464 - accuracy: 0.6190 - val_loss: 1.0742 - val_accuracy: 0.5000
# Epoch 8/80
# 2/2 [==============================] - 0s 165ms/step - loss: 1.0364 - accuracy: 0.6190 - val_loss: 1.0708 - val_accuracy: 0.5000
# Epoch 9/80
# 2/2 [==============================] - 0s 31ms/step - loss: 1.0254 - accuracy: 0.6190 - val_loss: 1.0675 - val_accuracy: 0.5000
# Epoch 10/80
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0141 - accuracy: 0.6190 - val_loss: 1.0644 - val_accuracy: 0.5000
# Epoch 11/80
# 2/2 [==============================] - 0s 34ms/step - loss: 1.0024 - accuracy: 0.6190 - val_loss: 1.0614 - val_accuracy: 0.5000
# Epoch 12/80
# 2/2 [==============================] - 0s 165ms/step - loss: 0.9897 - accuracy: 0.6190 - val_loss: 1.0582 - val_accuracy: 0.5000
# Epoch 13/80
# 2/2 [==============================] - 0s 163ms/step - loss: 0.9773 - accuracy: 0.6190 - val_loss: 1.0550 - val_accuracy: 0.5000
# Epoch 14/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9641 - accuracy: 0.6190 - val_loss: 1.0518 - val_accuracy: 0.5000
# Epoch 15/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9499 - accuracy: 0.6190 - val_loss: 1.0484 - val_accuracy: 0.5000
# Epoch 16/80
# 2/2 [==============================] - 0s 162ms/step - loss: 0.9351 - accuracy: 0.6190 - val_loss: 1.0447 - val_accuracy: 0.5000
# Epoch 17/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9203 - accuracy: 0.6190 - val_loss: 1.0412 - val_accuracy: 0.5000
# Epoch 18/80
# 2/2 [==============================] - 0s 163ms/step - loss: 0.9063 - accuracy: 0.6190 - val_loss: 1.0374 - val_accuracy: 0.5000
# Epoch 19/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8898 - accuracy: 0.6190 - val_loss: 1.0331 - val_accuracy: 0.5000
# Epoch 20/80
# 2/2 [==============================] - 0s 38ms/step - loss: 0.8744 - accuracy: 0.6190 - val_loss: 1.0289 - val_accuracy: 0.5000
# Epoch 21/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.8582 - accuracy: 0.6190 - val_loss: 1.0248 - val_accuracy: 0.5000
# Epoch 22/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8421 - accuracy: 0.6190 - val_loss: 1.0209 - val_accuracy: 0.5000
# Epoch 23/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8266 - accuracy: 0.6190 - val_loss: 1.0171 - val_accuracy: 0.5000
# Epoch 24/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8107 - accuracy: 0.6190 - val_loss: 1.0113 - val_accuracy: 0.5000
# Epoch 25/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7940 - accuracy: 0.6190 - val_loss: 1.0038 - val_accuracy: 0.5000
# Epoch 26/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7793 - accuracy: 0.6190 - val_loss: 0.9944 - val_accuracy: 0.5000
# Epoch 27/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7641 - accuracy: 0.6429 - val_loss: 0.9828 - val_accuracy: 0.5000
# Epoch 28/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7480 - accuracy: 0.6429 - val_loss: 0.9692 - val_accuracy: 0.5000
# Epoch 29/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7326 - accuracy: 0.6548 - val_loss: 0.9536 - val_accuracy: 0.5455
# Epoch 30/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7179 - accuracy: 0.6548 - val_loss: 0.9344 - val_accuracy: 0.5455
# Epoch 31/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7030 - accuracy: 0.6548 - val_loss: 0.9124 - val_accuracy: 0.5455
# Epoch 32/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6875 - accuracy: 0.6786 - val_loss: 0.8885 - val_accuracy: 0.5455
# Epoch 33/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6721 - accuracy: 0.6786 - val_loss: 0.8638 - val_accuracy: 0.5455
# Epoch 34/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6576 - accuracy: 0.6786 - val_loss: 0.8380 - val_accuracy: 0.5455
# Epoch 35/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6429 - accuracy: 0.6786 - val_loss: 0.8118 - val_accuracy: 0.5455
# Epoch 36/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6289 - accuracy: 0.6786 - val_loss: 0.7851 - val_accuracy: 0.5455
# Epoch 37/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6149 - accuracy: 0.7143 - val_loss: 0.7595 - val_accuracy: 0.5455
# Epoch 38/80
# 2/2 [==============================] - 0s 169ms/step - loss: 0.6019 - accuracy: 0.7381 - val_loss: 0.7337 - val_accuracy: 0.6364
# Epoch 39/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5891 - accuracy: 0.7381 - val_loss: 0.7094 - val_accuracy: 0.6818
# Epoch 40/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5769 - accuracy: 0.7262 - val_loss: 0.6871 - val_accuracy: 0.6818
# Epoch 41/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5653 - accuracy: 0.7143 - val_loss: 0.6675 - val_accuracy: 0.6818
# Epoch 42/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5532 - accuracy: 0.7143 - val_loss: 0.6494 - val_accuracy: 0.6818
# Epoch 43/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5431 - accuracy: 0.7262 - val_loss: 0.6322 - val_accuracy: 0.7273
# Epoch 44/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5329 - accuracy: 0.7381 - val_loss: 0.6168 - val_accuracy: 0.7727
# Epoch 45/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5232 - accuracy: 0.7381 - val_loss: 0.6037 - val_accuracy: 0.7727
# Epoch 46/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5134 - accuracy: 0.7500 - val_loss: 0.5926 - val_accuracy: 0.7727
# Epoch 47/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5041 - accuracy: 0.7500 - val_loss: 0.5830 - val_accuracy: 0.8182
# Epoch 48/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4949 - accuracy: 0.7500 - val_loss: 0.5746 - val_accuracy: 0.8182
# Epoch 49/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4865 - accuracy: 0.7619 - val_loss: 0.5670 - val_accuracy: 0.8182
# Epoch 50/80
# 2/2 [==============================] - 0s 164ms/step - loss: 0.4777 - accuracy: 0.7857 - val_loss: 0.5601 - val_accuracy: 0.8182
# Epoch 51/80
# 2/2 [==============================] - 0s 47ms/step - loss: 0.4698 - accuracy: 0.7857 - val_loss: 0.5539 - val_accuracy: 0.8182
# Epoch 52/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4618 - accuracy: 0.7857 - val_loss: 0.5478 - val_accuracy: 0.8636
# Epoch 53/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4538 - accuracy: 0.7857 - val_loss: 0.5422 - val_accuracy: 0.8636
# Epoch 54/80
# 2/2 [==============================] - 0s 165ms/step - loss: 0.4463 - accuracy: 0.7857 - val_loss: 0.5373 - val_accuracy: 0.8636
# Epoch 55/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4384 - accuracy: 0.8095 - val_loss: 0.5323 - val_accuracy: 0.8636
# Epoch 56/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4314 - accuracy: 0.8095 - val_loss: 0.5274 - val_accuracy: 0.8636
# Epoch 57/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4241 - accuracy: 0.8095 - val_loss: 0.5226 - val_accuracy: 0.8636
# Epoch 58/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4169 - accuracy: 0.8333 - val_loss: 0.5185 - val_accuracy: 0.8636
# Epoch 59/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4099 - accuracy: 0.8333 - val_loss: 0.5140 - val_accuracy: 0.8636
# Epoch 60/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4033 - accuracy: 0.8452 - val_loss: 0.5095 - val_accuracy: 0.8636
# Epoch 61/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3970 - accuracy: 0.8452 - val_loss: 0.5056 - val_accuracy: 0.8636
# Epoch 62/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3907 - accuracy: 0.8452 - val_loss: 0.5029 - val_accuracy: 0.8636
# Epoch 63/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3841 - accuracy: 0.8452 - val_loss: 0.5008 - val_accuracy: 0.8636
# Epoch 64/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3773 - accuracy: 0.8571 - val_loss: 0.4988 - val_accuracy: 0.8636
# Epoch 65/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3714 - accuracy: 0.8690 - val_loss: 0.4967 - val_accuracy: 0.8636
# Epoch 66/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3650 - accuracy: 0.8690 - val_loss: 0.4939 - val_accuracy: 0.8636
# Epoch 67/80
# 2/2 [==============================] - 0s 165ms/step - loss: 0.3592 - accuracy: 0.8929 - val_loss: 0.4902 - val_accuracy: 0.8636
# Epoch 68/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3536 - accuracy: 0.9048 - val_loss: 0.4852 - val_accuracy: 0.8636
# Epoch 69/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3473 - accuracy: 0.9048 - val_loss: 0.4808 - val_accuracy: 0.8636
# Epoch 70/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3421 - accuracy: 0.9167 - val_loss: 0.4775 - val_accuracy: 0.8636
# Epoch 71/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3362 - accuracy: 0.9167 - val_loss: 0.4759 - val_accuracy: 0.8636
# Epoch 72/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3310 - accuracy: 0.9167 - val_loss: 0.4758 - val_accuracy: 0.8636
# Epoch 73/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3255 - accuracy: 0.9286 - val_loss: 0.4758 - val_accuracy: 0.8636
# Epoch 74/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3199 - accuracy: 0.9286 - val_loss: 0.4761 - val_accuracy: 0.8636
# Epoch 75/80
# 2/2 [==============================] - 0s 168ms/step - loss: 0.3149 - accuracy: 0.9405 - val_loss: 0.4765 - val_accuracy: 0.8636
# Epoch 76/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3099 - accuracy: 0.9405 - val_loss: 0.4764 - val_accuracy: 0.8636
# Epoch 77/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3050 - accuracy: 0.9524 - val_loss: 0.4761 - val_accuracy: 0.8636
# Epoch 78/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3004 - accuracy: 0.9524 - val_loss: 0.4756 - val_accuracy: 0.8636
# Epoch 79/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2958 - accuracy: 0.9524 - val_loss: 0.4744 - val_accuracy: 0.8636
# Epoch 80/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2910 - accuracy: 0.9524 - val_loss: 0.4699 - val_accuracy: 0.8636

# %%
scores_trainig = model.evaluate(X_train, y_train, verbose=1)
print("Training Loss: %f%%" % (scores_trainig[0]))
print("Training Accuracy: %.2f%%" % (scores_trainig[1]*100))
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2868 - accuracy: 0.9524
# Training Loss: 0.286841%
# Training Accuracy: 95.24%

# %%
scores_test = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss: %f%%" % (scores_test[0]))
print("Test Accuracy: %.2f%%" % (scores_test[1]*100))
# Out:
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4699 - accuracy: 0.8636
# Test Loss: 0.469904%
# Test Accuracy: 86.36%

# %%
import numpy as np

def predict_sequence(model,response):
    
    response= remove_stowords(response)
    #print(corps)
# Convert texts to sequences of integers
    sequences = tokenizer.texts_to_sequences(response)

# Pad sequences to ensure uniform length

    sequences = pad_sequences(sequences, max_sequence_length)
   
    
    #print(sequences)
    # Reshape the input for model prediction
    #input_data = np.array([sequences])
    
    #print(input_data)
    # Make predictions
    predicted_probs = model.predict(sequences)
    predicted_value= np.argmax(predicted_probs, axis=1)
    
    #print(predicted_classes)
   
    return predicted_value[0]

# %%
test=[' قصعة خبز ولبن وسمن.']

# %%
predict_sequence(model,test)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 2

# %%
from keras.models import load_model

# Assuming 'model' is your Keras model
model.save('model1.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
