# %%
import pandas as pd
import os
import numpy as np
from keras import utils
from tensorflow.keras.callbacks import TensorBoard
from time import time
import tensorflow as tf

# %%
question9 = pd.read_csv('/kaggle/input/last-question/Question_9.csv', sep=',')
question9.head()
# Out:
#    ID                                Question  \
# 0   9  ما هي السُّورة التي تعدُّ أمُّ الكتاب؟
# 1   9  ما هي السُّورة التي تعدُّ أمُّ الكتاب؟
# 2   9  ما هي السُّورة التي تعدُّ أمُّ الكتاب؟
# 3   9  ما هي السُّورة التي تعدُّ أمُّ الكتاب؟
# 4   9  ما هي السُّورة التي تعدُّ أمُّ الكتاب؟
#
#                                      Réponse  Score
# 0                              سورة الفاتحة.      2
# 1                                   الفاتحة.      1
# 2                              سورة الفاتحة.      2
# 3    السورة التي تعتبر أم الكتاب هي الفاتحة.      2
# 4  السورة الأولى في القرآن، وتُعرف بالفاتحة.      2

# %%
question9['Score'].unique()
# Out:
# array([2, 1, 0])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data = question9, x= 'Score')
plt.grid(True)
plt.show()

# %%
question9.isnull().sum()
# Out:
# ID          0
# Question    0
# Réponse     0
# Score       0
# dtype: int64

# %%
# rows_with_null_values = question9[question9['Réponse'].isnull()]

# # Now you can display or inspect the rows
# print(rows_with_null_values)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Assuming 'data' is your DataFrame and 'Score' is a column in your DataFrame
sns.set(style="darkgrid")

# Create the count plot
ax = sns.countplot(data=question9, x='Score')

# Calculate the percentage of each category
total = len(question9)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.1,
            f'{height/total:.1%}', ha="center")

# Format y-axis as percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))

plt.show()

# %%
question9.shape
# Out:
# (110, 4)

# %%
question9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        110 non-null    int64
#  1   Question  110 non-null    object
#  2   Réponse   110 non-null    object
#  3   Score     110 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.6+ KB

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install -U nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('arabic'))
#stop_words
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#data avant stopwrds removed
question9['Réponse']
# Out:
# 0                                  سورة الفاتحة.
# 1                                       الفاتحة.
# 2                                  سورة الفاتحة.
# 3        السورة التي تعتبر أم الكتاب هي الفاتحة.
# 4      السورة الأولى في القرآن، وتُعرف بالفاتحة.
#                          ...
# 105                               سورة النازعات.
# 106                                سورة الغاشية.
# 107                                سورة الشعراء.
# 108                                  سورة القمر.
# 109                                     الفاتحة.
# Name: Réponse, Length: 110, dtype: object

# %%
#Drop stop words
from nltk.stem.arlstem import ARLSTem
stemmmer = ARLSTem()

def remove_stowords(elements):
    corps = []
    for string in elements :
        string = nltk.sent_tokenize(string.strip())
        string = [ stemmmer.stem(word) for word in string if not word in stop_words ]
        string = ''.join(string)
        corps.append(string)
    return corps

# %%
corps9= remove_stowords(question9['Réponse'])

# %%
#data after applying stopwords
# corps9

# %%
# tokenization
from keras.preprocessing.text import Tokenizer,text_to_word_sequence , one_hot , text_to_word_sequence
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle




# Train tokenization
tokenizer = Tokenizer(filters=''''!"#$%&()+,-./:;<=>?@[\\]^{|}~\t\n÷×؛<>()&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ''''' )
#tokenizer = Tokenizer(filters='#' )

# Fit the tokenizer on the training texts
tokenizer.fit_on_texts(corps9)

with open('TokenizerModel9.pkl', 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(corps9)

# Pad sequences to ensure uniform length
max_sequence_length = max(len(s) for s in sequences)
sequences = pad_sequences(sequences, max_sequence_length)

# Get the word-to-index mapping
vocab_dict = tokenizer.word_index

# Calculate the vocabulary size
vocab_size = len(vocab_dict) + 1

#print(vocab_dict)

# %%
max_sequence_length
# Out:
# 10

# %%
# vocab_dict

# %%
# !pip3 install gensim
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.3.0)

# %%
from gensim.models import KeyedVectors
fasttext_model = KeyedVectors.load_word2vec_format("/kaggle/input/fast-text-translation-data/fast_text_files/vectors/wiki.ar.vec")

# %%
# Word Embedding
from keras.layers import Embedding
import numpy as np

# Embedding Dimension
EMBEDDING_DIM = 300

# Total number of words in the vocabulary, including an index for unknown words
num_words = len(vocab_dict) + 1

# Counter for words not present in the FastText model
count = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

# Iterate through each word in the vocabulary
for word, idx in vocab_dict.items():
    # Check if the word is present in the FastText model
    if word in fasttext_model:
        # If yes, assign the FastText model's embedding vector to the word in the matrix
        embedding_matrix[idx] = fasttext_model.get_vector(word)
    else:
        # If the word is not present, increment the counter and print a message
        count += 1
        print("Word does not exist in the vocabulary ---> " + word)

       # Note: We could also assign a special embedding vector for unknown words.
        embedding_matrix[idx] = fasttext_model.get_vector("unk")
# Out:
# Word does not exist in the vocabulary ---> النبا

# %%
embedding_matrix
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-5.03970027e-01,  8.05329978e-01,  5.25479972e-01, ...,
#         -2.84979999e-01,  1.30530000e-01, -1.46019995e-01],
#        [-2.52180010e-01,  1.26980007e-01,  3.39060009e-01, ...,
#          9.69429985e-02, -5.29460013e-01,  2.88580004e-02],
#        ...,
#        [-2.06389993e-01,  3.32610011e-02, -4.65490013e-01, ...,
#         -1.42830002e-04, -1.78159997e-01, -2.79200007e-03],
#        [-3.17559987e-01,  2.81179994e-01,  3.15840006e-01, ...,
#          3.91030014e-01, -2.13929996e-01,  1.85920000e-01],
#        [-3.88359994e-01, -4.74120006e-02, -1.19099997e-01, ...,
#         -1.45199999e-01,  7.56770015e-01, -4.72170003e-02]])

# %%
X = sequences

# %%
# X

# %%
Score = question9['Score']
y = tf.keras.utils.to_categorical(
    Score, num_classes=3, dtype='float32'
)

# %%
# y

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
y_test.shape
# Out:
# (33, 3)

# %%
# from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.regularizers import l2
from tensorflow.keras.regularizers import l1
from keras.layers import Dropout

input_dim=vocab_size
output_dim=33
input_length=max_sequence_length


# Define the LSTM model
model = Sequential()
model.add(Embedding(input_dim=input_dim, output_dim=output_dim, input_length=input_length))
model.add(LSTM(units=10,kernel_regularizer=l2(0.0001)))
model.add(Dense(3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                    batch_size=64, epochs=150, verbose=1)



plt.figure(figsize=(16, 6))
# Courbe de perte
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Courbe de perte et de validation')
plt.xlabel('Époque')
plt.ylabel('Perte')
plt.legend()


# Courbe de précision
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Courbe de précision et de validation')
plt.xlabel('Époque')
plt.ylabel('Précision')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/150
# 2/2 [==============================] - 3s 685ms/step - loss: 1.0953 - accuracy: 0.5325 - val_loss: 1.0932 - val_accuracy: 0.6061
# Epoch 2/150
# 2/2 [==============================] - 0s 36ms/step - loss: 1.0886 - accuracy: 0.7143 - val_loss: 1.0888 - val_accuracy: 0.6061
# Epoch 3/150
# 2/2 [==============================] - 0s 225ms/step - loss: 1.0818 - accuracy: 0.7273 - val_loss: 1.0844 - val_accuracy: 0.6061
# Epoch 4/150
# 2/2 [==============================] - 0s 30ms/step - loss: 1.0753 - accuracy: 0.7403 - val_loss: 1.0798 - val_accuracy: 0.6061
# Epoch 5/150
# 2/2 [==============================] - 0s 227ms/step - loss: 1.0688 - accuracy: 0.7403 - val_loss: 1.0750 - val_accuracy: 0.6061
# Epoch 6/150
# 2/2 [==============================] - 0s 228ms/step - loss: 1.0618 - accuracy: 0.7403 - val_loss: 1.0701 - val_accuracy: 0.6061
# Epoch 7/150
# 2/2 [==============================] - 0s 31ms/step - loss: 1.0545 - accuracy: 0.7403 - val_loss: 1.0651 - val_accuracy: 0.6061
# Epoch 8/150
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0472 - accuracy: 0.7403 - val_loss: 1.0598 - val_accuracy: 0.6061
# Epoch 9/150
# 2/2 [==============================] - 0s 31ms/step - loss: 1.0393 - accuracy: 0.7403 - val_loss: 1.0542 - val_accuracy: 0.6061
# Epoch 10/150
# 2/2 [==============================] - 0s 232ms/step - loss: 1.0314 - accuracy: 0.7403 - val_loss: 1.0483 - val_accuracy: 0.6061
# Epoch 11/150
# 2/2 [==============================] - 0s 31ms/step - loss: 1.0225 - accuracy: 0.7403 - val_loss: 1.0420 - val_accuracy: 0.6061
# Epoch 12/150
# 2/2 [==============================] - 0s 30ms/step - loss: 1.0133 - accuracy: 0.7403 - val_loss: 1.0354 - val_accuracy: 0.6061
# Epoch 13/150
# 2/2 [==============================] - 0s 229ms/step - loss: 1.0033 - accuracy: 0.7273 - val_loss: 1.0285 - val_accuracy: 0.6061
# Epoch 14/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9935 - accuracy: 0.7273 - val_loss: 1.0213 - val_accuracy: 0.6061
# Epoch 15/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9827 - accuracy: 0.7273 - val_loss: 1.0137 - val_accuracy: 0.6061
# Epoch 16/150
# 2/2 [==============================] - 0s 228ms/step - loss: 0.9713 - accuracy: 0.7273 - val_loss: 1.0058 - val_accuracy: 0.6061
# Epoch 17/150
# 2/2 [==============================] - 0s 255ms/step - loss: 0.9597 - accuracy: 0.7143 - val_loss: 0.9977 - val_accuracy: 0.6061
# Epoch 18/150
# 2/2 [==============================] - 0s 41ms/step - loss: 0.9474 - accuracy: 0.7273 - val_loss: 0.9893 - val_accuracy: 0.6061
# Epoch 19/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.9341 - accuracy: 0.7273 - val_loss: 0.9807 - val_accuracy: 0.6061
# Epoch 20/150
# 2/2 [==============================] - 0s 36ms/step - loss: 0.9215 - accuracy: 0.7273 - val_loss: 0.9718 - val_accuracy: 0.6061
# Epoch 21/150
# 2/2 [==============================] - 0s 39ms/step - loss: 0.9077 - accuracy: 0.7273 - val_loss: 0.9627 - val_accuracy: 0.6061
# Epoch 22/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8935 - accuracy: 0.7273 - val_loss: 0.9534 - val_accuracy: 0.6061
# Epoch 23/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8793 - accuracy: 0.7273 - val_loss: 0.9441 - val_accuracy: 0.6061
# Epoch 24/150
# 2/2 [==============================] - 0s 236ms/step - loss: 0.8646 - accuracy: 0.7273 - val_loss: 0.9348 - val_accuracy: 0.6061
# Epoch 25/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8494 - accuracy: 0.7273 - val_loss: 0.9259 - val_accuracy: 0.6061
# Epoch 26/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8346 - accuracy: 0.7273 - val_loss: 0.9170 - val_accuracy: 0.6061
# Epoch 27/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8189 - accuracy: 0.7273 - val_loss: 0.9082 - val_accuracy: 0.6061
# Epoch 28/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8038 - accuracy: 0.7273 - val_loss: 0.8995 - val_accuracy: 0.6061
# Epoch 29/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7888 - accuracy: 0.7273 - val_loss: 0.8909 - val_accuracy: 0.6061
# Epoch 30/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7733 - accuracy: 0.7403 - val_loss: 0.8826 - val_accuracy: 0.6061
# Epoch 31/150
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7589 - accuracy: 0.7532 - val_loss: 0.8750 - val_accuracy: 0.6061
# Epoch 32/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7446 - accuracy: 0.7532 - val_loss: 0.8674 - val_accuracy: 0.6061
# Epoch 33/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7304 - accuracy: 0.7532 - val_loss: 0.8593 - val_accuracy: 0.6061
# Epoch 34/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7161 - accuracy: 0.7532 - val_loss: 0.8507 - val_accuracy: 0.6061
# Epoch 35/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7023 - accuracy: 0.7532 - val_loss: 0.8414 - val_accuracy: 0.6364
# Epoch 36/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6879 - accuracy: 0.7532 - val_loss: 0.8310 - val_accuracy: 0.6364
# Epoch 37/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6732 - accuracy: 0.7532 - val_loss: 0.8200 - val_accuracy: 0.6364
# Epoch 38/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6591 - accuracy: 0.7532 - val_loss: 0.8087 - val_accuracy: 0.6364
# Epoch 39/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6445 - accuracy: 0.7532 - val_loss: 0.7984 - val_accuracy: 0.6364
# Epoch 40/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6304 - accuracy: 0.7532 - val_loss: 0.7880 - val_accuracy: 0.6364
# Epoch 41/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6166 - accuracy: 0.7532 - val_loss: 0.7774 - val_accuracy: 0.6364
# Epoch 42/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6035 - accuracy: 0.7532 - val_loss: 0.7676 - val_accuracy: 0.6364
# Epoch 43/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5901 - accuracy: 0.7532 - val_loss: 0.7587 - val_accuracy: 0.6364
# Epoch 44/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5770 - accuracy: 0.7532 - val_loss: 0.7497 - val_accuracy: 0.6364
# Epoch 45/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5643 - accuracy: 0.7532 - val_loss: 0.7400 - val_accuracy: 0.6364
# Epoch 46/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5513 - accuracy: 0.7532 - val_loss: 0.7301 - val_accuracy: 0.6364
# Epoch 47/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5387 - accuracy: 0.7532 - val_loss: 0.7207 - val_accuracy: 0.6364
# Epoch 48/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5264 - accuracy: 0.7532 - val_loss: 0.7113 - val_accuracy: 0.6364
# Epoch 49/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5142 - accuracy: 0.7532 - val_loss: 0.7021 - val_accuracy: 0.6364
# Epoch 50/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5020 - accuracy: 0.7532 - val_loss: 0.6933 - val_accuracy: 0.6364
# Epoch 51/150
# 2/2 [==============================] - 0s 244ms/step - loss: 0.4901 - accuracy: 0.7532 - val_loss: 0.6846 - val_accuracy: 0.6364
# Epoch 52/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4786 - accuracy: 0.7662 - val_loss: 0.6759 - val_accuracy: 0.6364
# Epoch 53/150
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4675 - accuracy: 0.8052 - val_loss: 0.6678 - val_accuracy: 0.8485
# Epoch 54/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4561 - accuracy: 0.9610 - val_loss: 0.6605 - val_accuracy: 0.8485
# Epoch 55/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4451 - accuracy: 0.9610 - val_loss: 0.6536 - val_accuracy: 0.8485
# Epoch 56/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4347 - accuracy: 0.9610 - val_loss: 0.6462 - val_accuracy: 0.8485
# Epoch 57/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4239 - accuracy: 0.9610 - val_loss: 0.6379 - val_accuracy: 0.8485
# Epoch 58/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4137 - accuracy: 0.9610 - val_loss: 0.6292 - val_accuracy: 0.8485
# Epoch 59/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4036 - accuracy: 0.9610 - val_loss: 0.6205 - val_accuracy: 0.8485
# Epoch 60/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3933 - accuracy: 0.9610 - val_loss: 0.6122 - val_accuracy: 0.8485
# Epoch 61/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3839 - accuracy: 0.9610 - val_loss: 0.6041 - val_accuracy: 0.8485
# Epoch 62/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3743 - accuracy: 0.9610 - val_loss: 0.5963 - val_accuracy: 0.8788
# Epoch 63/150
# 2/2 [==============================] - 0s 243ms/step - loss: 0.3650 - accuracy: 0.9740 - val_loss: 0.5883 - val_accuracy: 0.8788
# Epoch 64/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3560 - accuracy: 0.9740 - val_loss: 0.5802 - val_accuracy: 0.8788
# Epoch 65/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3474 - accuracy: 0.9740 - val_loss: 0.5722 - val_accuracy: 0.8788
# Epoch 66/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3391 - accuracy: 0.9740 - val_loss: 0.5641 - val_accuracy: 0.8788
# Epoch 67/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3311 - accuracy: 0.9740 - val_loss: 0.5561 - val_accuracy: 0.8788
# Epoch 68/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3231 - accuracy: 0.9740 - val_loss: 0.5482 - val_accuracy: 0.8788
# Epoch 69/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3154 - accuracy: 0.9740 - val_loss: 0.5402 - val_accuracy: 0.8788
# Epoch 70/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3075 - accuracy: 0.9740 - val_loss: 0.5326 - val_accuracy: 0.8788
# Epoch 71/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2999 - accuracy: 0.9740 - val_loss: 0.5252 - val_accuracy: 0.8788
# Epoch 72/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2927 - accuracy: 0.9740 - val_loss: 0.5179 - val_accuracy: 0.8788
# Epoch 73/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2859 - accuracy: 0.9740 - val_loss: 0.5113 - val_accuracy: 0.8788
# Epoch 74/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2795 - accuracy: 0.9740 - val_loss: 0.5050 - val_accuracy: 0.8788
# Epoch 75/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2732 - accuracy: 0.9740 - val_loss: 0.4990 - val_accuracy: 0.8788
# Epoch 76/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2667 - accuracy: 0.9740 - val_loss: 0.4930 - val_accuracy: 0.8788
# Epoch 77/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2605 - accuracy: 0.9740 - val_loss: 0.4872 - val_accuracy: 0.8788
# Epoch 78/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2540 - accuracy: 0.9740 - val_loss: 0.4818 - val_accuracy: 0.8788
# Epoch 79/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2481 - accuracy: 0.9740 - val_loss: 0.4765 - val_accuracy: 0.8788
# Epoch 80/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2423 - accuracy: 0.9740 - val_loss: 0.4711 - val_accuracy: 0.8788
# Epoch 81/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2370 - accuracy: 0.9740 - val_loss: 0.4657 - val_accuracy: 0.8788
# Epoch 82/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2316 - accuracy: 0.9740 - val_loss: 0.4599 - val_accuracy: 0.8788
# Epoch 83/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2263 - accuracy: 0.9740 - val_loss: 0.4535 - val_accuracy: 0.8788
# Epoch 84/150
# 2/2 [==============================] - 0s 233ms/step - loss: 0.2211 - accuracy: 0.9740 - val_loss: 0.4473 - val_accuracy: 0.8788
# Epoch 85/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2160 - accuracy: 0.9740 - val_loss: 0.4413 - val_accuracy: 0.8788
# Epoch 86/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2110 - accuracy: 0.9740 - val_loss: 0.4356 - val_accuracy: 0.8788
# Epoch 87/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2063 - accuracy: 0.9740 - val_loss: 0.4294 - val_accuracy: 0.8788
# Epoch 88/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2013 - accuracy: 0.9740 - val_loss: 0.4220 - val_accuracy: 0.8788
# Epoch 89/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1967 - accuracy: 0.9740 - val_loss: 0.4146 - val_accuracy: 0.8788
# Epoch 90/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1919 - accuracy: 0.9740 - val_loss: 0.4081 - val_accuracy: 0.8788
# Epoch 91/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1874 - accuracy: 0.9740 - val_loss: 0.4021 - val_accuracy: 0.8788
# Epoch 92/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1831 - accuracy: 0.9740 - val_loss: 0.3964 - val_accuracy: 0.8788
# Epoch 93/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1787 - accuracy: 0.9740 - val_loss: 0.3906 - val_accuracy: 0.8788
# Epoch 94/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1749 - accuracy: 0.9740 - val_loss: 0.3848 - val_accuracy: 0.8788
# Epoch 95/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1708 - accuracy: 0.9740 - val_loss: 0.3794 - val_accuracy: 0.8788
# Epoch 96/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1670 - accuracy: 0.9740 - val_loss: 0.3738 - val_accuracy: 0.8788
# Epoch 97/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1632 - accuracy: 0.9740 - val_loss: 0.3684 - val_accuracy: 0.8788
# Epoch 98/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1597 - accuracy: 0.9740 - val_loss: 0.3634 - val_accuracy: 0.8788
# Epoch 99/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1564 - accuracy: 0.9740 - val_loss: 0.3585 - val_accuracy: 0.8788
# Epoch 100/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1533 - accuracy: 0.9740 - val_loss: 0.3532 - val_accuracy: 0.8788
# Epoch 101/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1499 - accuracy: 0.9740 - val_loss: 0.3473 - val_accuracy: 0.8788
# Epoch 102/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1470 - accuracy: 0.9740 - val_loss: 0.3412 - val_accuracy: 0.8788
# Epoch 103/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1434 - accuracy: 0.9740 - val_loss: 0.3360 - val_accuracy: 0.8788
# Epoch 104/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1398 - accuracy: 0.9740 - val_loss: 0.3313 - val_accuracy: 0.8788
# Epoch 105/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1366 - accuracy: 0.9740 - val_loss: 0.3264 - val_accuracy: 0.8788
# Epoch 106/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1336 - accuracy: 0.9740 - val_loss: 0.3215 - val_accuracy: 0.8788
# Epoch 107/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1307 - accuracy: 0.9740 - val_loss: 0.3167 - val_accuracy: 0.9091
# Epoch 108/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1283 - accuracy: 0.9870 - val_loss: 0.3121 - val_accuracy: 0.9091
# Epoch 109/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1254 - accuracy: 0.9870 - val_loss: 0.3081 - val_accuracy: 0.9091
# Epoch 110/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1226 - accuracy: 0.9870 - val_loss: 0.3044 - val_accuracy: 0.9697
# Epoch 111/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1200 - accuracy: 1.0000 - val_loss: 0.3005 - val_accuracy: 0.9697
# Epoch 112/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1174 - accuracy: 1.0000 - val_loss: 0.2965 - val_accuracy: 0.9697
# Epoch 113/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1147 - accuracy: 1.0000 - val_loss: 0.2925 - val_accuracy: 0.9697
# Epoch 114/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1122 - accuracy: 1.0000 - val_loss: 0.2883 - val_accuracy: 0.9697
# Epoch 115/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1099 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9697
# Epoch 116/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1074 - accuracy: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.9697
# Epoch 117/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1051 - accuracy: 1.0000 - val_loss: 0.2770 - val_accuracy: 0.9697
# Epoch 118/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1030 - accuracy: 1.0000 - val_loss: 0.2736 - val_accuracy: 0.9697
# Epoch 119/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1008 - accuracy: 1.0000 - val_loss: 0.2703 - val_accuracy: 0.9697
# Epoch 120/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0989 - accuracy: 1.0000 - val_loss: 0.2671 - val_accuracy: 0.9697
# Epoch 121/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0968 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9697
# Epoch 122/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0948 - accuracy: 1.0000 - val_loss: 0.2613 - val_accuracy: 0.9697
# Epoch 123/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9697
# Epoch 124/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0909 - accuracy: 1.0000 - val_loss: 0.2562 - val_accuracy: 0.9697
# Epoch 125/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0892 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9697
# Epoch 126/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0874 - accuracy: 1.0000 - val_loss: 0.2513 - val_accuracy: 0.9697
# Epoch 127/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0858 - accuracy: 1.0000 - val_loss: 0.2490 - val_accuracy: 0.9697
# Epoch 128/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0841 - accuracy: 1.0000 - val_loss: 0.2469 - val_accuracy: 0.9697
# Epoch 129/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0827 - accuracy: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.9697
# Epoch 130/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0812 - accuracy: 1.0000 - val_loss: 0.2431 - val_accuracy: 0.9697
# Epoch 131/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0797 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9697
# Epoch 132/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0782 - accuracy: 1.0000 - val_loss: 0.2378 - val_accuracy: 0.9697
# Epoch 133/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0765 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.9697
# Epoch 134/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 0.2328 - val_accuracy: 0.9697
# Epoch 135/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9697
# Epoch 136/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.9697
# Epoch 137/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.9697
# Epoch 138/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0700 - accuracy: 1.0000 - val_loss: 0.2253 - val_accuracy: 0.9697
# Epoch 139/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0688 - accuracy: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9697
# Epoch 140/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0677 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9697
# Epoch 141/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0666 - accuracy: 1.0000 - val_loss: 0.2209 - val_accuracy: 0.9697
# Epoch 142/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.2196 - val_accuracy: 0.9697
# Epoch 143/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.2183 - val_accuracy: 0.9697
# Epoch 144/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0638 - accuracy: 1.0000 - val_loss: 0.2170 - val_accuracy: 0.9697
# Epoch 145/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0629 - accuracy: 1.0000 - val_loss: 0.2157 - val_accuracy: 0.9697
# Epoch 146/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9697
# Epoch 147/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9697
# Epoch 148/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0602 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9697
# Epoch 149/150
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9697
# Epoch 150/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0584 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9697

# %%
scores_trainig = model.evaluate(X_train, y_train, verbose=1)
print("Training Loss: %f%%" % (scores_trainig[0]))
print("Training Accuracy: %.2f%%" % (scores_trainig[1]*100))
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 1.0000
# Training Loss: 0.057538%
# Training Accuracy: 100.00%

# %%
scores_test = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss: %f%%" % (scores_test[0]))
print("Test Accuracy: %.2f%%" % (scores_test[1]*100))
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2081 - accuracy: 0.9697
# Test Loss: 0.208137%
# Test Accuracy: 96.97%

# %%
import numpy as np

def predict_sequence(model,response):
    
    response= remove_stowords(response)
    #print(corps)
# Convert texts to sequences of integers
    sequences = tokenizer.texts_to_sequences(response)

# Pad sequences to ensure uniform length

    sequences = pad_sequences(sequences, max_sequence_length)
   
    
    #print(sequences)
    # Reshape the input for model prediction
    #input_data = np.array([sequences])
    
    #print(input_data)
    # Make predictions
    predicted_probs = model.predict(sequences)
    predicted_value= np.argmax(predicted_probs, axis=1)
    
    #print(predicted_classes)
   
    return predicted_value[0]

# %%
test=[' أم الكتاب هي الفاتحة']

# %%
predict_sequence(model,test)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 2

# %%
from keras.models import load_model

# Assuming 'model' is your Keras model
model.save('model9.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
