# %%
import pandas as pd
import os
import numpy as np
from keras import utils
from tensorflow.keras.callbacks import TensorBoard
from time import time
import tensorflow as tf

# %%
question12 = pd.read_csv('/kaggle/input/datasetar/Data/Question_12.csv', sep=',')
question12.head()
# Out:
#    ID                                           Question  \
# 0  12  كم كان عمر النَّبيُّ -صلّى الله وعليه وسلّم- ع...
# 1  12  كم كان عمر النَّبيُّ -صلّى الله وعليه وسلّم- ع...
# 2  12  كم كان عمر النَّبيُّ -صلّى الله وعليه وسلّم- ع...
# 3  12  كم كان عمر النَّبيُّ -صلّى الله وعليه وسلّم- ع...
# 4  12  كم كان عمر النَّبيُّ -صلّى الله وعليه وسلّم- ع...
#
#                                              Réponse Score
# 0  كان عمره عند الوفاة ثلاث وستِّين سنةً، وقد توف...     2
# 1                                  ثلاث وستِّين سنةً     1
# 2                                  ثلاث وستِّين سنةً     1
# 3                                  ثلاث وستِّين سنةً     1
# 4                                  ثلاث وستِّين سنةً     1

# %%
question12['Score'].unique()
# Out:
# array(['2', '1', '0', ' 1', '  في السَّنة الثَّالثة عشرة للهجرة 2', nan],
#       dtype=object)

# %%
import pandas as pd

# Suppose data is your DataFrame
question12['Score'] = question12['Score'].astype(str)  # Ensure the 'Score' column is of string type

# Filter the 'Score' column
allowed_values = ['1', '0', '2']
question12 = question12[question12['Score'].isin(allowed_values)]

# Display the unique values in the 'Score' column after filtering
print(question12['Score'].unique())
# Out:
# ['2' '1' '0']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data = question12, x= 'Score')
plt.grid(True)
plt.show()

# %%
question12.isnull().sum()
# Out:
# ID          0
# Question    0
# Réponse     0
# Score       0
# dtype: int64

# %%
rows_with_null_values = question12[question12['Réponse'].isnull()]

# Now you can display or inspect the rows
print(rows_with_null_values)
# Out:
# Empty DataFrame
# Columns: [ID, Question, Réponse, Score]
# Index: []

# %%
# Assuming your DataFrame is named 'question4'
#
# question15.dropna(subset=['Réponse'], inplace=True)

# %%
question12['Réponse'].isna().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Assuming 'data' is your DataFrame and 'Score' is a column in your DataFrame
sns.set(style="darkgrid")

# Create the count plot
ax = sns.countplot(data=question12, x='Score')

# Calculate the percentage of each category
total = len(question12)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.1,
            f'{height/total:.1%}', ha="center")

# Format y-axis as percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))

plt.show()

# %%
question12.shape
# Out:
# (95, 4)

# %%
question12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        95 non-null     int64
#  1   Question  95 non-null     object
#  2   Réponse   95 non-null     object
#  3   Score     95 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.7+ KB

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with your dataset
# Replace 'your_column' with the actual column name you want to check for duplicates

# Check for duplicates based on all columns
duplicate_rows = question12[question12.duplicated()]

# Check for duplicates based on a specific column
duplicate_rows_specific_column = question12[question12.duplicated(subset=['Réponse'])]

# Get the number of duplicates
num_duplicates = len(duplicate_rows)
num_duplicates_specific_column = len(duplicate_rows_specific_column)

print(f"Total duplicates: {num_duplicates}")
print(f"Duplicates in 'Réponse': {num_duplicates_specific_column}")
# Out:
# Total duplicates: 16
# Duplicates in 'Réponse': 16

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install -U nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('arabic'))
#stop_words
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#data avant stopwrds removed
question12['Réponse']
# Out:
# 0     كان عمره عند الوفاة ثلاث وستِّين سنةً، وقد توف...
# 1                                     ثلاث وستِّين سنةً
# 2                                     ثلاث وستِّين سنةً
# 3                                     ثلاث وستِّين سنةً
# 4                                     ثلاث وستِّين سنةً
#                             ...
# 95     كان عمره ثلاثة وستون عامًا، وذلك في السنة الث...
# 96                                            سن الستين
# 97                            في عام الثانية عشر للهجرة
# 98                            في عام الرابعة عشر للهجرة
# 99                            في عام الخامسة عشر للهجرة
# Name: Réponse, Length: 95, dtype: object

# %%
#Drop stop words
from nltk.stem.arlstem import ARLSTem
stemmmer = ARLSTem()

def remove_stowords(elements):
    corps = []
    for string in elements :
        string = nltk.sent_tokenize(string.strip())
        string = [ stemmmer.stem(word) for word in string if not word in stop_words ]
        string = ''.join(string)
        corps.append(string)
    return corps

# %%
corps12 = remove_stowords(question12['Réponse'])

# %%
#data after applying stopwords
# corps4

# %%
# tokenization
from keras.preprocessing.text import Tokenizer,text_to_word_sequence , one_hot , text_to_word_sequence
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle




# Train tokenization
tokenizer = Tokenizer(filters=''''!"#$%&()+,-./:;<=>?@[\\]^{|}~\t\n÷×؛<>()&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ''''' )
#tokenizer = Tokenizer(filters='#' )

# Fit the tokenizer on the training texts
tokenizer.fit_on_texts(corps12)

with open('TokenizerModel12.pkl', 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(corps12)

# Pad sequences to ensure uniform length
max_sequence_length = max(len(s) for s in sequences)
sequences = pad_sequences(sequences, max_sequence_length)

# Get the word-to-index mapping
vocab_dict = tokenizer.word_index

# Calculate the vocabulary size
vocab_size = len(vocab_dict) + 1

#print(vocab_dict)

# %%
max_sequence_length
# Out:
# 24

# %%
# vocab_dict

# %%
# !pip3 install gensim
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.3.0)

# %%
from gensim.models import KeyedVectors
fasttext_model = KeyedVectors.load_word2vec_format("/kaggle/input/fast-text-translation-data/fast_text_files/vectors/wiki.ar.vec")

# %%
# Word Embedding
from keras.layers import Embedding
import numpy as np

# Embedding Dimension
EMBEDDING_DIM = 300

# Total number of words in the vocabulary, including an index for unknown words
num_words = len(vocab_dict) + 1

# Counter for words not present in the FastText model
count = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

# Iterate through each word in the vocabulary
for word, idx in vocab_dict.items():
    # Check if the word is present in the FastText model
    if word in fasttext_model:
        # If yes, assign the FastText model's embedding vector to the word in the matrix
        embedding_matrix[idx] = fasttext_model.get_vector(word)
    else:
        # If the word is not present, increment the counter and print a message
        count += 1
        print("Word does not exist in the vocabulary ---> " + word)

       # Note: We could also assign a special embedding vector for unknown words.
        embedding_matrix[idx] = fasttext_model.get_vector("unk")
# Out:
# Word does not exist in the vocabulary ---> 13
# Word does not exist in the vocabulary ---> 40
# Word does not exist in the vocabulary ---> 63
# Word does not exist in the vocabulary ---> 632
# Word does not exist in the vocabulary ---> فاةالرسول

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.10685   , -0.062513  , -0.20926   , ...,  0.043603  ,
#          0.0070054 ,  0.097782  ],
#        [-0.11741   ,  0.059606  , -0.27281001, ..., -0.060135  ,
#          0.16716   ,  0.12272   ],
#        ...,
#        [ 0.21615   ,  0.21889   , -0.049481  , ..., -0.13906001,
#          0.12826   ,  0.36548001],
#        [-0.25591001, -0.37051001, -0.51898998, ..., -0.25441   ,
#         -0.12774999,  0.2683    ],
#        [ 0.068931  ,  0.38620001, -0.41514999, ..., -0.083423  ,
#          0.18935999,  0.051322  ]])

# %%
X = sequences

# %%
# X

# %%
Score = question12['Score']
y = tf.keras.utils.to_categorical(
    Score, num_classes=3, dtype='float32'
)

# %%
# y

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
y_test.shape
# Out:
# (29, 3)

# %%
# from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.regularizers import l2
from tensorflow.keras.regularizers import l1
from keras.layers import Dropout

input_dim=vocab_size
output_dim=33
input_length=max_sequence_length


# Define the LSTM model
model = Sequential()
model.add(Embedding(input_dim=input_dim, output_dim=output_dim, input_length=input_length))
model.add(LSTM(units=10,kernel_regularizer=l2(0.0001)))
model.add(Dense(3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                    batch_size=64, epochs=150, verbose=1)



plt.figure(figsize=(16, 6))
# Courbe de perte
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Courbe de perte et de validation')
plt.xlabel('Époque')
plt.ylabel('Perte')
plt.legend()


# Courbe de précision
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Courbe de précision et de validation')
plt.xlabel('Époque')
plt.ylabel('Précision')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/150
# 2/2 [==============================] - 3s 636ms/step - loss: 1.1052 - accuracy: 0.2727 - val_loss: 1.0979 - val_accuracy: 0.5517
# Epoch 2/150
# 2/2 [==============================] - 0s 185ms/step - loss: 1.1010 - accuracy: 0.3485 - val_loss: 1.0947 - val_accuracy: 0.5172
# Epoch 3/150
# 2/2 [==============================] - 0s 168ms/step - loss: 1.0979 - accuracy: 0.4091 - val_loss: 1.0921 - val_accuracy: 0.5862
# Epoch 4/150
# 2/2 [==============================] - 0s 168ms/step - loss: 1.0948 - accuracy: 0.4848 - val_loss: 1.0908 - val_accuracy: 0.5862
# Epoch 5/150
# 2/2 [==============================] - 0s 165ms/step - loss: 1.0916 - accuracy: 0.5606 - val_loss: 1.0897 - val_accuracy: 0.5862
# Epoch 6/150
# 2/2 [==============================] - 0s 165ms/step - loss: 1.0885 - accuracy: 0.6061 - val_loss: 1.0881 - val_accuracy: 0.6207
# Epoch 7/150
# 2/2 [==============================] - 0s 165ms/step - loss: 1.0853 - accuracy: 0.6212 - val_loss: 1.0860 - val_accuracy: 0.6207
# Epoch 8/150
# 2/2 [==============================] - 0s 33ms/step - loss: 1.0820 - accuracy: 0.6364 - val_loss: 1.0845 - val_accuracy: 0.6207
# Epoch 9/150
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0787 - accuracy: 0.6364 - val_loss: 1.0831 - val_accuracy: 0.6207
# Epoch 10/150
# 2/2 [==============================] - 0s 164ms/step - loss: 1.0750 - accuracy: 0.6515 - val_loss: 1.0809 - val_accuracy: 0.6207
# Epoch 11/150
# 2/2 [==============================] - 0s 33ms/step - loss: 1.0714 - accuracy: 0.6818 - val_loss: 1.0783 - val_accuracy: 0.5862
# Epoch 12/150
# 2/2 [==============================] - 0s 33ms/step - loss: 1.0676 - accuracy: 0.6667 - val_loss: 1.0751 - val_accuracy: 0.5862
# Epoch 13/150
# 2/2 [==============================] - 0s 39ms/step - loss: 1.0636 - accuracy: 0.6667 - val_loss: 1.0716 - val_accuracy: 0.5862
# Epoch 14/150
# 2/2 [==============================] - 0s 36ms/step - loss: 1.0593 - accuracy: 0.6515 - val_loss: 1.0682 - val_accuracy: 0.5862
# Epoch 15/150
# 2/2 [==============================] - 0s 38ms/step - loss: 1.0543 - accuracy: 0.6515 - val_loss: 1.0655 - val_accuracy: 0.5862
# Epoch 16/150
# 2/2 [==============================] - 0s 191ms/step - loss: 1.0489 - accuracy: 0.6818 - val_loss: 1.0629 - val_accuracy: 0.5517
# Epoch 17/150
# 2/2 [==============================] - 0s 165ms/step - loss: 1.0432 - accuracy: 0.6818 - val_loss: 1.0594 - val_accuracy: 0.5517
# Epoch 18/150
# 2/2 [==============================] - 0s 166ms/step - loss: 1.0372 - accuracy: 0.6970 - val_loss: 1.0551 - val_accuracy: 0.5517
# Epoch 19/150
# 2/2 [==============================] - 0s 33ms/step - loss: 1.0309 - accuracy: 0.7273 - val_loss: 1.0509 - val_accuracy: 0.5517
# Epoch 20/150
# 2/2 [==============================] - 0s 173ms/step - loss: 1.0239 - accuracy: 0.7576 - val_loss: 1.0469 - val_accuracy: 0.5517
# Epoch 21/150
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0164 - accuracy: 0.7727 - val_loss: 1.0430 - val_accuracy: 0.6207
# Epoch 22/150
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0081 - accuracy: 0.8333 - val_loss: 1.0390 - val_accuracy: 0.4828
# Epoch 23/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9989 - accuracy: 0.7424 - val_loss: 1.0348 - val_accuracy: 0.5172
# Epoch 24/150
# 2/2 [==============================] - 0s 164ms/step - loss: 0.9888 - accuracy: 0.7424 - val_loss: 1.0302 - val_accuracy: 0.5517
# Epoch 25/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9776 - accuracy: 0.7121 - val_loss: 1.0266 - val_accuracy: 0.5172
# Epoch 26/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9658 - accuracy: 0.6970 - val_loss: 1.0253 - val_accuracy: 0.4828
# Epoch 27/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.9539 - accuracy: 0.6970 - val_loss: 1.0251 - val_accuracy: 0.4828
# Epoch 28/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9422 - accuracy: 0.6818 - val_loss: 1.0226 - val_accuracy: 0.4828
# Epoch 29/150
# 2/2 [==============================] - 0s 37ms/step - loss: 0.9310 - accuracy: 0.6515 - val_loss: 1.0187 - val_accuracy: 0.3448
# Epoch 30/150
# 2/2 [==============================] - 0s 38ms/step - loss: 0.9206 - accuracy: 0.6212 - val_loss: 1.0158 - val_accuracy: 0.3103
# Epoch 31/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.9107 - accuracy: 0.6061 - val_loss: 1.0155 - val_accuracy: 0.3103
# Epoch 32/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9018 - accuracy: 0.6061 - val_loss: 1.0188 - val_accuracy: 0.3103
# Epoch 33/150
# 2/2 [==============================] - 0s 172ms/step - loss: 0.8945 - accuracy: 0.6061 - val_loss: 1.0236 - val_accuracy: 0.3448
# Epoch 34/150
# 2/2 [==============================] - 0s 166ms/step - loss: 0.8887 - accuracy: 0.6212 - val_loss: 1.0235 - val_accuracy: 0.3448
# Epoch 35/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8815 - accuracy: 0.6212 - val_loss: 1.0127 - val_accuracy: 0.3448
# Epoch 36/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8723 - accuracy: 0.6212 - val_loss: 1.0022 - val_accuracy: 0.3448
# Epoch 37/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8633 - accuracy: 0.6212 - val_loss: 0.9872 - val_accuracy: 0.4138
# Epoch 38/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8525 - accuracy: 0.6515 - val_loss: 0.9653 - val_accuracy: 0.4483
# Epoch 39/150
# 2/2 [==============================] - 0s 165ms/step - loss: 0.8386 - accuracy: 0.6818 - val_loss: 0.9440 - val_accuracy: 0.5517
# Epoch 40/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8244 - accuracy: 0.6970 - val_loss: 0.9205 - val_accuracy: 0.5517
# Epoch 41/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8092 - accuracy: 0.7273 - val_loss: 0.8967 - val_accuracy: 0.6897
# Epoch 42/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7975 - accuracy: 0.7576 - val_loss: 0.8791 - val_accuracy: 0.6897
# Epoch 43/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7879 - accuracy: 0.7424 - val_loss: 0.8665 - val_accuracy: 0.6897
# Epoch 44/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7804 - accuracy: 0.7424 - val_loss: 0.8557 - val_accuracy: 0.6552
# Epoch 45/150
# 2/2 [==============================] - 0s 166ms/step - loss: 0.7723 - accuracy: 0.7727 - val_loss: 0.8457 - val_accuracy: 0.6552
# Epoch 46/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7624 - accuracy: 0.7879 - val_loss: 0.8371 - val_accuracy: 0.6552
# Epoch 47/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7521 - accuracy: 0.7879 - val_loss: 0.8292 - val_accuracy: 0.6552
# Epoch 48/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7412 - accuracy: 0.7879 - val_loss: 0.8200 - val_accuracy: 0.6897
# Epoch 49/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7301 - accuracy: 0.7727 - val_loss: 0.8087 - val_accuracy: 0.6897
# Epoch 50/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7197 - accuracy: 0.7727 - val_loss: 0.7981 - val_accuracy: 0.7241
# Epoch 51/150
# 2/2 [==============================] - 0s 166ms/step - loss: 0.7096 - accuracy: 0.7727 - val_loss: 0.7897 - val_accuracy: 0.7241
# Epoch 52/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6989 - accuracy: 0.7727 - val_loss: 0.7812 - val_accuracy: 0.7586
# Epoch 53/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6882 - accuracy: 0.7727 - val_loss: 0.7732 - val_accuracy: 0.7241
# Epoch 54/150
# 2/2 [==============================] - 0s 163ms/step - loss: 0.6784 - accuracy: 0.7727 - val_loss: 0.7639 - val_accuracy: 0.7241
# Epoch 55/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6690 - accuracy: 0.7727 - val_loss: 0.7485 - val_accuracy: 0.7241
# Epoch 56/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6599 - accuracy: 0.7727 - val_loss: 0.7336 - val_accuracy: 0.8966
# Epoch 57/150
# 2/2 [==============================] - 0s 167ms/step - loss: 0.6511 - accuracy: 0.8636 - val_loss: 0.7243 - val_accuracy: 0.8966
# Epoch 58/150
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6424 - accuracy: 0.8636 - val_loss: 0.7202 - val_accuracy: 0.8966
# Epoch 59/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6347 - accuracy: 0.8636 - val_loss: 0.7096 - val_accuracy: 0.8966
# Epoch 60/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6239 - accuracy: 0.8636 - val_loss: 0.6934 - val_accuracy: 0.8966
# Epoch 61/150
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6126 - accuracy: 0.8788 - val_loss: 0.6818 - val_accuracy: 0.8966
# Epoch 62/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6032 - accuracy: 0.8788 - val_loss: 0.6720 - val_accuracy: 0.8966
# Epoch 63/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5946 - accuracy: 0.9091 - val_loss: 0.6618 - val_accuracy: 0.8621
# Epoch 64/150
# 2/2 [==============================] - 0s 166ms/step - loss: 0.5873 - accuracy: 0.9242 - val_loss: 0.6546 - val_accuracy: 0.8621
# Epoch 65/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5815 - accuracy: 0.9394 - val_loss: 0.6504 - val_accuracy: 0.8621
# Epoch 66/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5758 - accuracy: 0.9394 - val_loss: 0.6477 - val_accuracy: 0.8621
# Epoch 67/150
# 2/2 [==============================] - 0s 166ms/step - loss: 0.5701 - accuracy: 0.9394 - val_loss: 0.6443 - val_accuracy: 0.8621
# Epoch 68/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5630 - accuracy: 0.9394 - val_loss: 0.6392 - val_accuracy: 0.8621
# Epoch 69/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5561 - accuracy: 0.9394 - val_loss: 0.6311 - val_accuracy: 0.8621
# Epoch 70/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5452 - accuracy: 0.9394 - val_loss: 0.6216 - val_accuracy: 0.8621
# Epoch 71/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5315 - accuracy: 0.8939 - val_loss: 0.6140 - val_accuracy: 0.8621
# Epoch 72/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5204 - accuracy: 0.8939 - val_loss: 0.6098 - val_accuracy: 0.8966
# Epoch 73/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5116 - accuracy: 0.9091 - val_loss: 0.6099 - val_accuracy: 0.8966
# Epoch 74/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5055 - accuracy: 0.9091 - val_loss: 0.6167 - val_accuracy: 0.7586
# Epoch 75/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5030 - accuracy: 0.8333 - val_loss: 0.6277 - val_accuracy: 0.7586
# Epoch 76/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5034 - accuracy: 0.8333 - val_loss: 0.6320 - val_accuracy: 0.7241
# Epoch 77/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5010 - accuracy: 0.8030 - val_loss: 0.6151 - val_accuracy: 0.7586
# Epoch 78/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4898 - accuracy: 0.8333 - val_loss: 0.5905 - val_accuracy: 0.8966
# Epoch 79/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4765 - accuracy: 0.8636 - val_loss: 0.5742 - val_accuracy: 0.8966
# Epoch 80/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4674 - accuracy: 0.9091 - val_loss: 0.5640 - val_accuracy: 0.8621
# Epoch 81/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4618 - accuracy: 0.9091 - val_loss: 0.5566 - val_accuracy: 0.8621
# Epoch 82/150
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4592 - accuracy: 0.9242 - val_loss: 0.5504 - val_accuracy: 0.8621
# Epoch 83/150
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4558 - accuracy: 0.9545 - val_loss: 0.5422 - val_accuracy: 0.8621
# Epoch 84/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4502 - accuracy: 0.9545 - val_loss: 0.5325 - val_accuracy: 0.8621
# Epoch 85/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4436 - accuracy: 0.9545 - val_loss: 0.5225 - val_accuracy: 0.8621
# Epoch 86/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4369 - accuracy: 0.9545 - val_loss: 0.5126 - val_accuracy: 0.8621
# Epoch 87/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4271 - accuracy: 0.9545 - val_loss: 0.5073 - val_accuracy: 0.8621
# Epoch 88/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4175 - accuracy: 0.9545 - val_loss: 0.5099 - val_accuracy: 0.8966
# Epoch 89/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4115 - accuracy: 0.9545 - val_loss: 0.5181 - val_accuracy: 0.8621
# Epoch 90/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4093 - accuracy: 0.9242 - val_loss: 0.5203 - val_accuracy: 0.8621
# Epoch 91/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4056 - accuracy: 0.9091 - val_loss: 0.5090 - val_accuracy: 0.8621
# Epoch 92/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3984 - accuracy: 0.9242 - val_loss: 0.4980 - val_accuracy: 0.8621
# Epoch 93/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3908 - accuracy: 0.9242 - val_loss: 0.4932 - val_accuracy: 0.8621
# Epoch 94/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3855 - accuracy: 0.9394 - val_loss: 0.4854 - val_accuracy: 0.8621
# Epoch 95/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3798 - accuracy: 0.9394 - val_loss: 0.4755 - val_accuracy: 0.8621
# Epoch 96/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3736 - accuracy: 0.9545 - val_loss: 0.4695 - val_accuracy: 0.8621
# Epoch 97/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3682 - accuracy: 0.9697 - val_loss: 0.4581 - val_accuracy: 0.8621
# Epoch 98/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3615 - accuracy: 0.9545 - val_loss: 0.4440 - val_accuracy: 0.8966
# Epoch 99/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3551 - accuracy: 0.9394 - val_loss: 0.4356 - val_accuracy: 0.8621
# Epoch 100/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3513 - accuracy: 0.9394 - val_loss: 0.4329 - val_accuracy: 0.8621
# Epoch 101/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3469 - accuracy: 0.9394 - val_loss: 0.4320 - val_accuracy: 0.8621
# Epoch 102/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3421 - accuracy: 0.9545 - val_loss: 0.4312 - val_accuracy: 0.8621
# Epoch 103/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3384 - accuracy: 0.9545 - val_loss: 0.4310 - val_accuracy: 0.8621
# Epoch 104/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3346 - accuracy: 0.9545 - val_loss: 0.4306 - val_accuracy: 0.8621
# Epoch 105/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3305 - accuracy: 0.9545 - val_loss: 0.4275 - val_accuracy: 0.8621
# Epoch 106/150
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3242 - accuracy: 0.9545 - val_loss: 0.4250 - val_accuracy: 0.8621
# Epoch 107/150
# 2/2 [==============================] - 0s 164ms/step - loss: 0.3177 - accuracy: 0.9697 - val_loss: 0.4244 - val_accuracy: 0.8966
# Epoch 108/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3125 - accuracy: 0.9697 - val_loss: 0.4240 - val_accuracy: 0.8966
# Epoch 109/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3082 - accuracy: 0.9697 - val_loss: 0.4211 - val_accuracy: 0.8621
# Epoch 110/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3038 - accuracy: 0.9697 - val_loss: 0.4141 - val_accuracy: 0.8276
# Epoch 111/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2989 - accuracy: 0.9697 - val_loss: 0.4046 - val_accuracy: 0.8621
# Epoch 112/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2940 - accuracy: 0.9697 - val_loss: 0.3939 - val_accuracy: 0.8621
# Epoch 113/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2905 - accuracy: 0.9545 - val_loss: 0.3861 - val_accuracy: 0.8621
# Epoch 114/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2864 - accuracy: 0.9697 - val_loss: 0.3816 - val_accuracy: 0.8966
# Epoch 115/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2824 - accuracy: 0.9697 - val_loss: 0.3793 - val_accuracy: 0.8966
# Epoch 116/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2779 - accuracy: 0.9697 - val_loss: 0.3775 - val_accuracy: 0.8621
# Epoch 117/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2734 - accuracy: 0.9697 - val_loss: 0.3758 - val_accuracy: 0.8621
# Epoch 118/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2690 - accuracy: 0.9697 - val_loss: 0.3764 - val_accuracy: 0.8621
# Epoch 119/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2647 - accuracy: 0.9697 - val_loss: 0.3735 - val_accuracy: 0.8621
# Epoch 120/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2603 - accuracy: 0.9697 - val_loss: 0.3652 - val_accuracy: 0.8621
# Epoch 121/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2573 - accuracy: 0.9697 - val_loss: 0.3611 - val_accuracy: 0.8621
# Epoch 122/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2538 - accuracy: 0.9697 - val_loss: 0.3636 - val_accuracy: 0.8621
# Epoch 123/150
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2500 - accuracy: 0.9697 - val_loss: 0.3669 - val_accuracy: 0.8621
# Epoch 124/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2463 - accuracy: 0.9697 - val_loss: 0.3710 - val_accuracy: 0.8621
# Epoch 125/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2428 - accuracy: 0.9697 - val_loss: 0.3763 - val_accuracy: 0.8621
# Epoch 126/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2398 - accuracy: 0.9697 - val_loss: 0.3730 - val_accuracy: 0.8621
# Epoch 127/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2365 - accuracy: 0.9697 - val_loss: 0.3649 - val_accuracy: 0.8621
# Epoch 128/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2332 - accuracy: 0.9697 - val_loss: 0.3531 - val_accuracy: 0.8621
# Epoch 129/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2304 - accuracy: 0.9697 - val_loss: 0.3404 - val_accuracy: 0.8621
# Epoch 130/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2287 - accuracy: 0.9697 - val_loss: 0.3342 - val_accuracy: 0.8621
# Epoch 131/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2265 - accuracy: 0.9697 - val_loss: 0.3302 - val_accuracy: 0.8621
# Epoch 132/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2239 - accuracy: 0.9697 - val_loss: 0.3248 - val_accuracy: 0.8966
# Epoch 133/150
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2231 - accuracy: 0.9697 - val_loss: 0.3208 - val_accuracy: 0.8966
# Epoch 134/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2225 - accuracy: 0.9697 - val_loss: 0.3182 - val_accuracy: 0.8966
# Epoch 135/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2204 - accuracy: 0.9697 - val_loss: 0.3153 - val_accuracy: 0.8966
# Epoch 136/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2167 - accuracy: 0.9697 - val_loss: 0.3134 - val_accuracy: 0.8966
# Epoch 137/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2113 - accuracy: 0.9697 - val_loss: 0.3155 - val_accuracy: 0.8621
# Epoch 138/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2057 - accuracy: 0.9697 - val_loss: 0.3209 - val_accuracy: 0.8621
# Epoch 139/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2013 - accuracy: 0.9697 - val_loss: 0.3274 - val_accuracy: 0.8621
# Epoch 140/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1982 - accuracy: 0.9697 - val_loss: 0.3322 - val_accuracy: 0.8621
# Epoch 141/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1956 - accuracy: 0.9697 - val_loss: 0.3316 - val_accuracy: 0.8621
# Epoch 142/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1930 - accuracy: 0.9697 - val_loss: 0.3301 - val_accuracy: 0.8621
# Epoch 143/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1905 - accuracy: 0.9697 - val_loss: 0.3308 - val_accuracy: 0.8621
# Epoch 144/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1885 - accuracy: 0.9697 - val_loss: 0.3332 - val_accuracy: 0.8621
# Epoch 145/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1871 - accuracy: 0.9848 - val_loss: 0.3358 - val_accuracy: 0.8621
# Epoch 146/150
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1860 - accuracy: 0.9848 - val_loss: 0.3301 - val_accuracy: 0.8621
# Epoch 147/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1833 - accuracy: 0.9848 - val_loss: 0.3180 - val_accuracy: 0.8621
# Epoch 148/150
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1794 - accuracy: 0.9848 - val_loss: 0.3053 - val_accuracy: 0.8621
# Epoch 149/150
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1757 - accuracy: 0.9848 - val_loss: 0.2961 - val_accuracy: 0.8621
# Epoch 150/150
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1732 - accuracy: 0.9697 - val_loss: 0.2920 - val_accuracy: 0.8966

# %%
scores_trainig = model.evaluate(X_train, y_train, verbose=1)
print("Training Loss: %f%%" % (scores_trainig[0]))
print("Training Accuracy: %.2f%%" % (scores_trainig[1]*100))
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1716 - accuracy: 0.9697
# Training Loss: 0.171562%
# Training Accuracy: 96.97%

# %%
scores_test = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss: %f%%" % (scores_test[0]))
print("Test Accuracy: %.2f%%" % (scores_test[1]*100))
# Out:
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2920 - accuracy: 0.8966
# Test Loss: 0.292041%
# Test Accuracy: 89.66%

# %%
import numpy as np

def predict_sequence(model,response):
    
    response= remove_stowords(response)
    #print(corps)
# Convert texts to sequences of integers
    sequences = tokenizer.texts_to_sequences(response)

# Pad sequences to ensure uniform length

    sequences = pad_sequences(sequences, max_sequence_length)
   
    
    #print(sequences)
    # Reshape the input for model prediction
    #input_data = np.array([sequences])
    
    #print(input_data)
    # Make predictions
    predicted_probs = model.predict(sequences)
    predicted_value= np.argmax(predicted_probs, axis=1)
    
    #print(predicted_classes)
   
    return predicted_value[0]

# %%
test=['عمره 63 سنة، في عام 632 م']

# %%
predict_sequence(model,test)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 2

# %%
from keras.models import load_model

# Assuming 'model' is your Keras model
model.save('model12.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
