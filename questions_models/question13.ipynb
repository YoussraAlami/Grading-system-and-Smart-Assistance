# %%
import pandas as pd
import os
import numpy as np
from keras import utils
from tensorflow.keras.callbacks import TensorBoard
from time import time
import tensorflow as tf

# %%
question13 = pd.read_csv('/kaggle/input/datasetar/Data/Question_13.csv', sep=',')
question13.head()
# Out:
#    ID                                           Question  \
# 0  13  كم كان عدد الصَّلوات التي فرضها الله- تعالى- ع...
# 1  13  كم كان عدد الصَّلوات التي فرضها الله- تعالى- ع...
# 2  13  كم كان عدد الصَّلوات التي فرضها الله- تعالى- ع...
# 3  13  كم كان عدد الصَّلوات التي فرضها الله- تعالى- ع...
# 4  13  كم كان عدد الصَّلوات التي فرضها الله- تعالى- ع...
#
#                                              Réponse  Score
# 0                                        خمسون صلاةً    1.0
# 1  عدد الصلوات التي فرضها الله -تعالى- على المسلم...    2.0
# 2  في البداية، كان عدد الصلوات التي فرضها الله عل...    2.0
# 3  خمسون صلاة كانت العدد الأصلي للصلوات التي فُرِ...    2.0
# 4  قد فرض الله -تعالى- في البداية خمسون صلاة على ...    2.0

# %%
question13['Score'].unique()
# Out:
# array([ 1.,  2.,  0., nan])

# %%
# Supprimer les valeurs NaN de la colonne 'Score'
question13 = question13.dropna(subset=['Score'])

# Garder uniquement les valeurs 1, 2, et 0
allowed_values = [0, 1, 2]
question13_filtered = question13[question13['Score'].isin(allowed_values)]

# Afficher les valeurs uniques après filtration
print(question13_filtered['Score'].unique())
# Out:
# [1. 2. 0.]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data = question13, x= 'Score')
plt.grid(True)
plt.show()

# %%
question13.isnull().sum()
# Out:
# ID          0
# Question    0
# Réponse     0
# Score       0
# dtype: int64

# %%
rows_with_null_values = question13[question13['Réponse'].isnull()]

# Now you can display or inspect the rows
print(rows_with_null_values)
# Out:
# Empty DataFrame
# Columns: [ID, Question, Réponse, Score]
# Index: []

# %%
# Assuming your DataFrame is named 'question4'
#
# question15.dropna(subset=['Réponse'], inplace=True)

# %%
question13['Réponse'].isna().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Assuming 'data' is your DataFrame and 'Score' is a column in your DataFrame
sns.set(style="darkgrid")

# Create the count plot
ax = sns.countplot(data=question13, x='Score')

# Calculate the percentage of each category
total = len(question13)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.1,
            f'{height/total:.1%}', ha="center")

# Format y-axis as percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))

plt.show()

# %%
question13.shape
# Out:
# (124, 4)

# %%
question13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124 entries, 0 to 124
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        124 non-null    int64
#  1   Question  124 non-null    object
#  2   Réponse   124 non-null    object
#  3   Score     124 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.8+ KB

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with your dataset
# Replace 'your_column' with the actual column name you want to check for duplicates

# Check for duplicates based on all columns
duplicate_rows = question13[question13.duplicated()]

# Check for duplicates based on a specific column
duplicate_rows_specific_column = question13[question13.duplicated(subset=['Réponse'])]

# Get the number of duplicates
num_duplicates = len(duplicate_rows)
num_duplicates_specific_column = len(duplicate_rows_specific_column)

print(f"Total duplicates: {num_duplicates}")
print(f"Duplicates in 'Réponse': {num_duplicates_specific_column}")
# Out:
# Total duplicates: 59
# Duplicates in 'Réponse': 60

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install -U nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('arabic'))
#stop_words
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#data avant stopwrds removed
question13['Réponse']
# Out:
# 0                                            خمسون صلاةً
# 1      عدد الصلوات التي فرضها الله -تعالى- على المسلم...
# 2      في البداية، كان عدد الصلوات التي فرضها الله عل...
# 3      خمسون صلاة كانت العدد الأصلي للصلوات التي فُرِ...
# 4      قد فرض الله -تعالى- في البداية خمسون صلاة على ...
#                              ...
# 119                                    خمسة وثمانون صلاة
# 120                                      مئة وعشرون صلاة
# 121                                      خمسة وستون صلاة
# 122                                     خمسة وسبعون صلاة
# 124                                           خمسون صلاة
# Name: Réponse, Length: 124, dtype: object

# %%
#Drop stop words
from nltk.stem.arlstem import ARLSTem
stemmmer = ARLSTem()

def remove_stowords(elements):
    corps = []
    for string in elements :
        string = nltk.sent_tokenize(string.strip())
        string = [ stemmmer.stem(word) for word in string if not word in stop_words ]
        string = ''.join(string)
        corps.append(string)
    return corps

# %%
corps13 = remove_stowords(question13['Réponse'])

# %%
#data after applying stopwords
# corps4

# %%
# tokenization
from keras.preprocessing.text import Tokenizer,text_to_word_sequence , one_hot , text_to_word_sequence
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle




# Train tokenization
tokenizer = Tokenizer(filters=''''!"#$%&()+,-./:;<=>?@[\\]^{|}~\t\n÷×؛<>()&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ''''' )
#tokenizer = Tokenizer(filters='#' )

# Fit the tokenizer on the training texts
tokenizer.fit_on_texts(corps13)

with open('TokenizerModel13.pkl', 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(corps13)

# Pad sequences to ensure uniform length
max_sequence_length = max(len(s) for s in sequences)
sequences = pad_sequences(sequences, max_sequence_length)

# Get the word-to-index mapping
vocab_dict = tokenizer.word_index

# Calculate the vocabulary size
vocab_size = len(vocab_dict) + 1

#print(vocab_dict)

# %%
max_sequence_length
# Out:
# 12

# %%
# vocab_dict

# %%
# !pip3 install gensim
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.3.0)

# %%
from gensim.models import KeyedVectors
fasttext_model = KeyedVectors.load_word2vec_format("/kaggle/input/fast-text-translation-data/fast_text_files/vectors/wiki.ar.vec")

# %%
# Word Embedding
from keras.layers import Embedding
import numpy as np

# Embedding Dimension
EMBEDDING_DIM = 300

# Total number of words in the vocabulary, including an index for unknown words
num_words = len(vocab_dict) + 1

# Counter for words not present in the FastText model
count = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

# Iterate through each word in the vocabulary
for word, idx in vocab_dict.items():
    # Check if the word is present in the FastText model
    if word in fasttext_model:
        # If yes, assign the FastText model's embedding vector to the word in the matrix
        embedding_matrix[idx] = fasttext_model.get_vector(word)
    else:
        # If the word is not present, increment the counter and print a message
        count += 1
        print("Word does not exist in the vocabulary ---> " + word)

       # Note: We could also assign a special embedding vector for unknown words.
        embedding_matrix[idx] = fasttext_model.get_vector("unk")
# Out:
# Word does not exist in the vocabulary ---> كالامر

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.54225999,  0.10713   ,  0.22708   , ...,  0.22496   ,
#         -0.1864    , -0.063528  ],
#        [ 0.087478  ,  0.04968   ,  0.20388   , ..., -0.054158  ,
#         -0.0082092 ,  0.40757   ],
#        ...,
#        [ 0.16508   ,  0.19840001, -0.14619   , ..., -0.13265   ,
#         -0.016581  ,  0.14132001],
#        [ 0.40810999,  0.29166999, -0.13060001, ..., -0.024265  ,
#         -0.12441   ,  0.36649999],
#        [ 0.57666999,  0.26113999,  0.10029   , ..., -0.14012   ,
#         -0.43338999,  0.12344   ]])

# %%
X = sequences

# %%
# X

# %%
Score = question13['Score']
y = tf.keras.utils.to_categorical(
    Score, num_classes=3, dtype='float32'
)

# %%
# y

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y_test.shape
# Out:
# (25, 3)

# %%
# from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.regularizers import l2
from tensorflow.keras.regularizers import l1
from keras.layers import Dropout

input_dim=vocab_size
output_dim=33
input_length=max_sequence_length


# Define the LSTM model
model = Sequential()
model.add(Embedding(input_dim=input_dim, output_dim=output_dim, input_length=input_length))
model.add(LSTM(units=10,kernel_regularizer=l2(0.001)))
model.add(Dense(3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                    batch_size=64, epochs=80, verbose=1)



plt.figure(figsize=(16, 6))
# Courbe de perte
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Courbe de perte et de validation')
plt.xlabel('Époque')
plt.ylabel('Perte')
plt.legend()


# Courbe de précision
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Courbe de précision et de validation')
plt.xlabel('Époque')
plt.ylabel('Précision')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/80
# 2/2 [==============================] - 3s 485ms/step - loss: 1.1322 - accuracy: 0.4141 - val_loss: 1.1282 - val_accuracy: 0.6000
# Epoch 2/80
# 2/2 [==============================] - 0s 163ms/step - loss: 1.1254 - accuracy: 0.6162 - val_loss: 1.1217 - val_accuracy: 0.7200
# Epoch 3/80
# 2/2 [==============================] - 0s 164ms/step - loss: 1.1187 - accuracy: 0.6465 - val_loss: 1.1150 - val_accuracy: 0.8000
# Epoch 4/80
# 2/2 [==============================] - 0s 162ms/step - loss: 1.1118 - accuracy: 0.7273 - val_loss: 1.1082 - val_accuracy: 0.8400
# Epoch 5/80
# 2/2 [==============================] - 0s 162ms/step - loss: 1.1051 - accuracy: 0.7172 - val_loss: 1.1012 - val_accuracy: 0.8400
# Epoch 6/80
# 2/2 [==============================] - 0s 45ms/step - loss: 1.0978 - accuracy: 0.7172 - val_loss: 1.0939 - val_accuracy: 0.8400
# Epoch 7/80
# 2/2 [==============================] - 0s 34ms/step - loss: 1.0905 - accuracy: 0.7273 - val_loss: 1.0863 - val_accuracy: 0.8400
# Epoch 8/80
# 2/2 [==============================] - 0s 181ms/step - loss: 1.0827 - accuracy: 0.7273 - val_loss: 1.0785 - val_accuracy: 0.8400
# Epoch 9/80
# 2/2 [==============================] - 0s 181ms/step - loss: 1.0748 - accuracy: 0.7374 - val_loss: 1.0703 - val_accuracy: 0.8400
# Epoch 10/80
# 2/2 [==============================] - 0s 38ms/step - loss: 1.0660 - accuracy: 0.7374 - val_loss: 1.0616 - val_accuracy: 0.8400
# Epoch 11/80
# 2/2 [==============================] - 0s 44ms/step - loss: 1.0568 - accuracy: 0.7374 - val_loss: 1.0523 - val_accuracy: 0.8400
# Epoch 12/80
# 2/2 [==============================] - 0s 163ms/step - loss: 1.0467 - accuracy: 0.7374 - val_loss: 1.0424 - val_accuracy: 0.8400
# Epoch 13/80
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0362 - accuracy: 0.7374 - val_loss: 1.0314 - val_accuracy: 0.8400
# Epoch 14/80
# 2/2 [==============================] - 0s 163ms/step - loss: 1.0250 - accuracy: 0.7374 - val_loss: 1.0196 - val_accuracy: 0.8400
# Epoch 15/80
# 2/2 [==============================] - 0s 162ms/step - loss: 1.0126 - accuracy: 0.7374 - val_loss: 1.0069 - val_accuracy: 0.8400
# Epoch 16/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9994 - accuracy: 0.7374 - val_loss: 0.9934 - val_accuracy: 0.9200
# Epoch 17/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9848 - accuracy: 0.8687 - val_loss: 0.9789 - val_accuracy: 0.9200
# Epoch 18/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.9692 - accuracy: 0.8889 - val_loss: 0.9633 - val_accuracy: 0.9200
# Epoch 19/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9536 - accuracy: 0.9091 - val_loss: 0.9466 - val_accuracy: 0.9200
# Epoch 20/80
# 2/2 [==============================] - 0s 165ms/step - loss: 0.9357 - accuracy: 0.9596 - val_loss: 0.9286 - val_accuracy: 0.9200
# Epoch 21/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.9168 - accuracy: 0.9596 - val_loss: 0.9096 - val_accuracy: 0.9200
# Epoch 22/80
# 2/2 [==============================] - 0s 165ms/step - loss: 0.8972 - accuracy: 0.9596 - val_loss: 0.8895 - val_accuracy: 0.9200
# Epoch 23/80
# 2/2 [==============================] - 0s 162ms/step - loss: 0.8767 - accuracy: 0.9596 - val_loss: 0.8685 - val_accuracy: 0.9200
# Epoch 24/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8555 - accuracy: 0.9596 - val_loss: 0.8468 - val_accuracy: 0.9200
# Epoch 25/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8337 - accuracy: 0.9596 - val_loss: 0.8243 - val_accuracy: 0.9200
# Epoch 26/80
# 2/2 [==============================] - 0s 162ms/step - loss: 0.8119 - accuracy: 0.9596 - val_loss: 0.8017 - val_accuracy: 0.9200
# Epoch 27/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7897 - accuracy: 0.9596 - val_loss: 0.7792 - val_accuracy: 0.9200
# Epoch 28/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7675 - accuracy: 0.9596 - val_loss: 0.7570 - val_accuracy: 0.9200
# Epoch 29/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7457 - accuracy: 0.9596 - val_loss: 0.7352 - val_accuracy: 0.8800
# Epoch 30/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.7247 - accuracy: 0.8687 - val_loss: 0.7142 - val_accuracy: 0.8800
# Epoch 31/80
# 2/2 [==============================] - 0s 165ms/step - loss: 0.7039 - accuracy: 0.8687 - val_loss: 0.6944 - val_accuracy: 0.8800
# Epoch 32/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6855 - accuracy: 0.8687 - val_loss: 0.6752 - val_accuracy: 0.9200
# Epoch 33/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6676 - accuracy: 0.8687 - val_loss: 0.6573 - val_accuracy: 0.9200
# Epoch 34/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6497 - accuracy: 0.8485 - val_loss: 0.6406 - val_accuracy: 0.9200
# Epoch 35/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6342 - accuracy: 0.8485 - val_loss: 0.6250 - val_accuracy: 0.9200
# Epoch 36/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6192 - accuracy: 0.8485 - val_loss: 0.6105 - val_accuracy: 0.9200
# Epoch 37/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6055 - accuracy: 0.8485 - val_loss: 0.5968 - val_accuracy: 0.9200
# Epoch 38/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5930 - accuracy: 0.8485 - val_loss: 0.5841 - val_accuracy: 0.9200
# Epoch 39/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5805 - accuracy: 0.8485 - val_loss: 0.5714 - val_accuracy: 0.9200
# Epoch 40/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5685 - accuracy: 0.8485 - val_loss: 0.5594 - val_accuracy: 0.9200
# Epoch 41/80
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5576 - accuracy: 0.8485 - val_loss: 0.5475 - val_accuracy: 0.9200
# Epoch 42/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5472 - accuracy: 0.8485 - val_loss: 0.5364 - val_accuracy: 0.9200
# Epoch 43/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5371 - accuracy: 0.8485 - val_loss: 0.5262 - val_accuracy: 0.9200
# Epoch 44/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5269 - accuracy: 0.8485 - val_loss: 0.5172 - val_accuracy: 0.9200
# Epoch 45/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5176 - accuracy: 0.8687 - val_loss: 0.5087 - val_accuracy: 0.9200
# Epoch 46/80
# 2/2 [==============================] - 0s 168ms/step - loss: 0.5082 - accuracy: 0.8687 - val_loss: 0.5009 - val_accuracy: 0.9200
# Epoch 47/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4991 - accuracy: 0.8687 - val_loss: 0.4931 - val_accuracy: 0.9200
# Epoch 48/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4903 - accuracy: 0.8788 - val_loss: 0.4864 - val_accuracy: 0.9600
# Epoch 49/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4813 - accuracy: 0.8990 - val_loss: 0.4799 - val_accuracy: 0.9600
# Epoch 50/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4725 - accuracy: 0.8990 - val_loss: 0.4749 - val_accuracy: 0.9600
# Epoch 51/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4642 - accuracy: 0.9899 - val_loss: 0.4700 - val_accuracy: 0.9600
# Epoch 52/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4555 - accuracy: 1.0000 - val_loss: 0.4648 - val_accuracy: 0.9600
# Epoch 53/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4474 - accuracy: 1.0000 - val_loss: 0.4592 - val_accuracy: 0.9600
# Epoch 54/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4390 - accuracy: 1.0000 - val_loss: 0.4544 - val_accuracy: 0.9200
# Epoch 55/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4307 - accuracy: 1.0000 - val_loss: 0.4500 - val_accuracy: 0.9200
# Epoch 56/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4228 - accuracy: 1.0000 - val_loss: 0.4448 - val_accuracy: 0.9200
# Epoch 57/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4143 - accuracy: 1.0000 - val_loss: 0.4399 - val_accuracy: 0.9200
# Epoch 58/80
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4063 - accuracy: 1.0000 - val_loss: 0.4361 - val_accuracy: 0.9200
# Epoch 59/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3978 - accuracy: 1.0000 - val_loss: 0.4313 - val_accuracy: 0.9200
# Epoch 60/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3899 - accuracy: 1.0000 - val_loss: 0.4271 - val_accuracy: 0.9200
# Epoch 61/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3815 - accuracy: 1.0000 - val_loss: 0.4217 - val_accuracy: 0.9200
# Epoch 62/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3736 - accuracy: 1.0000 - val_loss: 0.4143 - val_accuracy: 0.9200
# Epoch 63/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3652 - accuracy: 1.0000 - val_loss: 0.4075 - val_accuracy: 0.9200
# Epoch 64/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3574 - accuracy: 1.0000 - val_loss: 0.4011 - val_accuracy: 0.9200
# Epoch 65/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3492 - accuracy: 1.0000 - val_loss: 0.3978 - val_accuracy: 0.9200
# Epoch 66/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3408 - accuracy: 1.0000 - val_loss: 0.3936 - val_accuracy: 0.9200
# Epoch 67/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3326 - accuracy: 1.0000 - val_loss: 0.3898 - val_accuracy: 0.9200
# Epoch 68/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3245 - accuracy: 1.0000 - val_loss: 0.3859 - val_accuracy: 0.9200
# Epoch 69/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3165 - accuracy: 0.9899 - val_loss: 0.3824 - val_accuracy: 0.9200
# Epoch 70/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3086 - accuracy: 0.9899 - val_loss: 0.3776 - val_accuracy: 0.9200
# Epoch 71/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3007 - accuracy: 0.9899 - val_loss: 0.3716 - val_accuracy: 0.9200
# Epoch 72/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2928 - accuracy: 1.0000 - val_loss: 0.3682 - val_accuracy: 0.9200
# Epoch 73/80
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2854 - accuracy: 0.9899 - val_loss: 0.3639 - val_accuracy: 0.9200
# Epoch 74/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2779 - accuracy: 0.9899 - val_loss: 0.3618 - val_accuracy: 0.9200
# Epoch 75/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2706 - accuracy: 0.9899 - val_loss: 0.3559 - val_accuracy: 0.9200
# Epoch 76/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2630 - accuracy: 0.9899 - val_loss: 0.3466 - val_accuracy: 0.9200
# Epoch 77/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2561 - accuracy: 1.0000 - val_loss: 0.3366 - val_accuracy: 0.9200
# Epoch 78/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2494 - accuracy: 1.0000 - val_loss: 0.3296 - val_accuracy: 0.9200
# Epoch 79/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2428 - accuracy: 1.0000 - val_loss: 0.3282 - val_accuracy: 0.9200
# Epoch 80/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2355 - accuracy: 1.0000 - val_loss: 0.3326 - val_accuracy: 0.9200

# %%
scores_trainig = model.evaluate(X_train, y_train, verbose=1)
print("Training Loss: %f%%" % (scores_trainig[0]))
print("Training Accuracy: %.2f%%" % (scores_trainig[1]*100))
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2303 - accuracy: 1.0000
# Training Loss: 0.230267%
# Training Accuracy: 100.00%

# %%
scores_test = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss: %f%%" % (scores_test[0]))
print("Test Accuracy: %.2f%%" % (scores_test[1]*100))
# Out:
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3326 - accuracy: 0.9200
# Test Loss: 0.332616%
# Test Accuracy: 92.00%

# %%
import numpy as np

def predict_sequence(model,response):
    
    response= remove_stowords(response)
    #print(corps)
# Convert texts to sequences of integers
    sequences = tokenizer.texts_to_sequences(response)

# Pad sequences to ensure uniform length

    sequences = pad_sequences(sequences, max_sequence_length)
   
    
    #print(sequences)
    # Reshape the input for model prediction
    #input_data = np.array([sequences])
    
    #print(input_data)
    # Make predictions
    predicted_probs = model.predict(sequences)
    predicted_value= np.argmax(predicted_probs, axis=1)
    
    #print(predicted_classes)
   
    return predicted_value[0]

# %%
test=['فرض الله خمسون صلاة في البداية']

# %%
predict_sequence(model,test)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 2

# %%
from keras.models import load_model

# Assuming 'model' is your Keras model
model.save('model13.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
