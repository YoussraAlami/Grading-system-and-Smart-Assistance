# %%
import pandas as pd
import os
import numpy as np
from keras import utils
from tensorflow.keras.callbacks import TensorBoard
from time import time
import tensorflow as tf

# %%
question15 = pd.read_csv('/kaggle/input/datasetar/Data/Question_15.csv', sep=',')
question15.head()
# Out:
#    ID                                        Question  \
# 0  15  من هو مؤذِّن رسول الله -صلّى الله عليه وسلّم-؟
# 1  15  من هو مؤذِّن رسول الله -صلّى الله عليه وسلّم-؟
# 2  15  من هو مؤذِّن رسول الله -صلّى الله عليه وسلّم-؟
# 3  15  من هو مؤذِّن رسول الله -صلّى الله عليه وسلّم-؟
# 4  15  من هو مؤذِّن رسول الله -صلّى الله عليه وسلّم-؟
#
#                                              Réponse  Score
# 0                         بلال بن رباح -رضي الله عنه      2
# 1  بلال بن رباح هو مؤذِّن رسول الله -صلّى الله عل...      2
# 2  المؤذِّن الذي كان يُكلِّف بالأذان لرسول الله -...      2
# 3  رسول الله -صلّى الله عليه وسلّم- كان يُؤذِّن ل...      2
# 4  بلال بن رباح هو الرجل الذي قام بالأذان لرسول ا...      2

# %%
question15['Score'].unique()
# Out:
# array([2, 0, 1])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data = question15, x= 'Score')
plt.grid(True)
plt.show()

# %%
question15.isnull().sum()
# Out:
# ID          0
# Question    0
# Réponse     0
# Score       0
# dtype: int64

# %%
rows_with_null_values = question15[question15['Réponse'].isnull()]

# Now you can display or inspect the rows
print(rows_with_null_values)
# Out:
# Empty DataFrame
# Columns: [ID, Question, Réponse, Score]
# Index: []

# %%
# Assuming your DataFrame is named 'question4'
#
# question15.dropna(subset=['Réponse'], inplace=True)

# %%
question15['Réponse'].isna().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Assuming 'data' is your DataFrame and 'Score' is a column in your DataFrame
sns.set(style="darkgrid")

# Create the count plot
ax = sns.countplot(data=question15, x='Score')

# Calculate the percentage of each category
total = len(question15)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.1,
            f'{height/total:.1%}', ha="center")

# Format y-axis as percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))

plt.show()

# %%
question15.shape
# Out:
# (91, 4)

# %%
question15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        91 non-null     int64
#  1   Question  91 non-null     object
#  2   Réponse   91 non-null     object
#  3   Score     91 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 3.0+ KB

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with your dataset
# Replace 'your_column' with the actual column name you want to check for duplicates

# Check for duplicates based on all columns
duplicate_rows = question15[question15.duplicated()]

# Check for duplicates based on a specific column
duplicate_rows_specific_column = question15[question15.duplicated(subset=['Réponse'])]

# Get the number of duplicates
num_duplicates = len(duplicate_rows)
num_duplicates_specific_column = len(duplicate_rows_specific_column)

print(f"Total duplicates: {num_duplicates}")
print(f"Duplicates in 'Réponse': {num_duplicates_specific_column}")
# Out:
# Total duplicates: 44
# Duplicates in 'Réponse': 44

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install -U nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('arabic'))
#stop_words
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#data avant stopwrds removed
question15['Réponse']
# Out:
# 0                            بلال بن رباح -رضي الله عنه
# 1     بلال بن رباح هو مؤذِّن رسول الله -صلّى الله عل...
# 2     المؤذِّن الذي كان يُكلِّف بالأذان لرسول الله -...
# 3     رسول الله -صلّى الله عليه وسلّم- كان يُؤذِّن ل...
# 4     بلال بن رباح هو الرجل الذي قام بالأذان لرسول ا...
#                             ...
# 86                                      علي بن أبي طالب
# 87                                                  علي
# 88                                                    ب
# 89    الصحابي بلال بن رباح كان يُعتبر مؤذِّنًا للنبي...
# 90    الصحابي بلال بن رباح كان يُعتبر مؤذِّنًا للنبي...
# Name: Réponse, Length: 91, dtype: object

# %%
#Drop stop words
from nltk.stem.arlstem import ARLSTem
stemmmer = ARLSTem()

def remove_stowords(elements):
    corps = []
    for string in elements :
        string = nltk.sent_tokenize(string.strip())
        string = [ stemmmer.stem(word) for word in string if not word in stop_words ]
        string = ''.join(string)
        corps.append(string)
    return corps

# %%
corps15 = remove_stowords(question15['Réponse'])

# %%
#data after applying stopwords
# corps4

# %%
# tokenization
from keras.preprocessing.text import Tokenizer,text_to_word_sequence , one_hot , text_to_word_sequence
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle




# Train tokenization
tokenizer = Tokenizer(filters=''''!"#$%&()+,-./:;<=>?@[\\]^{|}~\t\n÷×؛<>()&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ''''' )
#tokenizer = Tokenizer(filters='#' )

# Fit the tokenizer on the training texts
tokenizer.fit_on_texts(corps15)

with open('TokenizerModel15.pkl', 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(corps15)

# Pad sequences to ensure uniform length
max_sequence_length = max(len(s) for s in sequences)
sequences = pad_sequences(sequences, max_sequence_length)

# Get the word-to-index mapping
vocab_dict = tokenizer.word_index

# Calculate the vocabulary size
vocab_size = len(vocab_dict) + 1

#print(vocab_dict)

# %%
max_sequence_length
# Out:
# 18

# %%
# vocab_dict

# %%
# !pip3 install gensim
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.3.0)

# %%
from gensim.models import KeyedVectors
fasttext_model = KeyedVectors.load_word2vec_format("/kaggle/input/fast-text-translation-data/fast_text_files/vectors/wiki.ar.vec")

# %%
# Word Embedding
from keras.layers import Embedding
import numpy as np

# Embedding Dimension
EMBEDDING_DIM = 300

# Total number of words in the vocabulary, including an index for unknown words
num_words = len(vocab_dict) + 1

# Counter for words not present in the FastText model
count = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

# Iterate through each word in the vocabulary
for word, idx in vocab_dict.items():
    # Check if the word is present in the FastText model
    if word in fasttext_model:
        # If yes, assign the FastText model's embedding vector to the word in the matrix
        embedding_matrix[idx] = fasttext_model.get_vector(word)
    else:
        # If the word is not present, increment the counter and print a message
        count += 1
        print("Word does not exist in the vocabulary ---> " + word)

       # Note: We could also assign a special embedding vector for unknown words.
        embedding_matrix[idx] = fasttext_model.get_vector("unk")
# Out:
# Word does not exist in the vocabulary ---> بالاذان
# Word does not exist in the vocabulary ---> مؤذنه
# Word does not exist in the vocabulary ---> ﷺ
# Word does not exist in the vocabulary ---> عثم
# Word does not exist in the vocabulary ---> ببلال
# Word does not exist in the vocabulary ---> لاذان
# Word does not exist in the vocabulary ---> كمؤذن

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.024347  , -0.019301  ,  0.075631  , ..., -0.023894  ,
#          0.061126  ,  0.3175    ],
#        [-0.21085   ,  0.022055  ,  0.085399  , ...,  0.19428   ,
#         -0.43158999,  0.63410002],
#        ...,
#        [-0.29938999, -0.23630001,  0.23103   , ..., -0.12371   ,
#         -0.24819   ,  0.31467   ],
#        [-0.31105   ,  0.11385   ,  0.36809999, ..., -0.083412  ,
#         -0.34974   , -0.15172   ],
#        [ 0.15209   ,  0.11129   ,  0.26304999, ..., -0.1179    ,
#         -0.1541    ,  0.38868999]])

# %%
X = sequences

# %%
# X

# %%
Score = question15['Score']
y = tf.keras.utils.to_categorical(
    Score, num_classes=3, dtype='float32'
)

# %%
# y

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y_test.shape
# Out:
# (19, 3)

# %%
# from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.regularizers import l2
from tensorflow.keras.regularizers import l1
from keras.layers import Dropout

input_dim=vocab_size
output_dim=33
input_length=max_sequence_length


# Define the LSTM model
model = Sequential()
model.add(Embedding(input_dim=input_dim, output_dim=output_dim, input_length=input_length))
model.add(LSTM(units=10,kernel_regularizer=l2(0.0001)))
model.add(Dense(3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                    batch_size=64, epochs=80, verbose=1)



plt.figure(figsize=(16, 6))
# Courbe de perte
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Courbe de perte et de validation')
plt.xlabel('Époque')
plt.ylabel('Perte')
plt.legend()


# Courbe de précision
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Courbe de précision et de validation')
plt.xlabel('Époque')
plt.ylabel('Précision')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/80
# 2/2 [==============================] - 3s 663ms/step - loss: 1.0965 - accuracy: 0.5556 - val_loss: 1.0928 - val_accuracy: 0.5789
# Epoch 2/80
# 2/2 [==============================] - 0s 165ms/step - loss: 1.0875 - accuracy: 0.7639 - val_loss: 1.0864 - val_accuracy: 0.6842
# Epoch 3/80
# 2/2 [==============================] - 0s 164ms/step - loss: 1.0786 - accuracy: 0.8194 - val_loss: 1.0798 - val_accuracy: 0.6842
# Epoch 4/80
# 2/2 [==============================] - 0s 174ms/step - loss: 1.0698 - accuracy: 0.8194 - val_loss: 1.0729 - val_accuracy: 0.6842
# Epoch 5/80
# 2/2 [==============================] - 0s 164ms/step - loss: 1.0614 - accuracy: 0.8333 - val_loss: 1.0659 - val_accuracy: 0.7368
# Epoch 6/80
# 2/2 [==============================] - 0s 172ms/step - loss: 1.0521 - accuracy: 0.8472 - val_loss: 1.0583 - val_accuracy: 0.7368
# Epoch 7/80
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0432 - accuracy: 0.8472 - val_loss: 1.0505 - val_accuracy: 0.7895
# Epoch 8/80
# 2/2 [==============================] - 0s 166ms/step - loss: 1.0334 - accuracy: 0.8611 - val_loss: 1.0424 - val_accuracy: 0.7895
# Epoch 9/80
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0231 - accuracy: 0.8611 - val_loss: 1.0338 - val_accuracy: 0.7895
# Epoch 10/80
# 2/2 [==============================] - 0s 45ms/step - loss: 1.0123 - accuracy: 0.8611 - val_loss: 1.0242 - val_accuracy: 0.7895
# Epoch 11/80
# 2/2 [==============================] - 0s 177ms/step - loss: 1.0012 - accuracy: 0.8611 - val_loss: 1.0137 - val_accuracy: 0.7895
# Epoch 12/80
# 2/2 [==============================] - 0s 179ms/step - loss: 0.9892 - accuracy: 0.8611 - val_loss: 1.0021 - val_accuracy: 0.7368
# Epoch 13/80
# 2/2 [==============================] - 0s 43ms/step - loss: 0.9768 - accuracy: 0.8472 - val_loss: 0.9894 - val_accuracy: 0.6842
# Epoch 14/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9643 - accuracy: 0.8472 - val_loss: 0.9759 - val_accuracy: 0.6842
# Epoch 15/80
# 2/2 [==============================] - 0s 179ms/step - loss: 0.9505 - accuracy: 0.8472 - val_loss: 0.9615 - val_accuracy: 0.6842
# Epoch 16/80
# 2/2 [==============================] - 0s 236ms/step - loss: 0.9353 - accuracy: 0.8472 - val_loss: 0.9460 - val_accuracy: 0.6842
# Epoch 17/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.9196 - accuracy: 0.8472 - val_loss: 0.9298 - val_accuracy: 0.6842
# Epoch 18/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.9027 - accuracy: 0.8472 - val_loss: 0.9136 - val_accuracy: 0.6842
# Epoch 19/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8840 - accuracy: 0.8472 - val_loss: 0.8966 - val_accuracy: 0.6842
# Epoch 20/80
# 2/2 [==============================] - 0s 165ms/step - loss: 0.8656 - accuracy: 0.8472 - val_loss: 0.8775 - val_accuracy: 0.6842
# Epoch 21/80
# 2/2 [==============================] - 0s 173ms/step - loss: 0.8458 - accuracy: 0.8472 - val_loss: 0.8568 - val_accuracy: 0.6842
# Epoch 22/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8249 - accuracy: 0.8472 - val_loss: 0.8356 - val_accuracy: 0.6842
# Epoch 23/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8030 - accuracy: 0.8472 - val_loss: 0.8135 - val_accuracy: 0.6842
# Epoch 24/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7801 - accuracy: 0.8472 - val_loss: 0.7896 - val_accuracy: 0.6842
# Epoch 25/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7569 - accuracy: 0.8472 - val_loss: 0.7647 - val_accuracy: 0.6842
# Epoch 26/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7329 - accuracy: 0.8472 - val_loss: 0.7403 - val_accuracy: 0.6842
# Epoch 27/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7079 - accuracy: 0.8472 - val_loss: 0.7161 - val_accuracy: 0.6842
# Epoch 28/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6839 - accuracy: 0.8472 - val_loss: 0.6920 - val_accuracy: 0.6842
# Epoch 29/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6596 - accuracy: 0.8472 - val_loss: 0.6693 - val_accuracy: 0.6842
# Epoch 30/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6368 - accuracy: 0.8472 - val_loss: 0.6483 - val_accuracy: 0.6842
# Epoch 31/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6146 - accuracy: 0.8472 - val_loss: 0.6280 - val_accuracy: 0.6842
# Epoch 32/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5935 - accuracy: 0.8472 - val_loss: 0.6091 - val_accuracy: 0.7368
# Epoch 33/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5740 - accuracy: 0.8611 - val_loss: 0.5924 - val_accuracy: 0.7368
# Epoch 34/80
# 2/2 [==============================] - 0s 182ms/step - loss: 0.5559 - accuracy: 0.8611 - val_loss: 0.5777 - val_accuracy: 0.7368
# Epoch 35/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5387 - accuracy: 0.8611 - val_loss: 0.5642 - val_accuracy: 0.7368
# Epoch 36/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5231 - accuracy: 0.8611 - val_loss: 0.5506 - val_accuracy: 0.7368
# Epoch 37/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5083 - accuracy: 0.8611 - val_loss: 0.5367 - val_accuracy: 0.7368
# Epoch 38/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4953 - accuracy: 0.8611 - val_loss: 0.5224 - val_accuracy: 0.7368
# Epoch 39/80
# 2/2 [==============================] - 0s 162ms/step - loss: 0.4836 - accuracy: 0.8611 - val_loss: 0.5087 - val_accuracy: 0.7368
# Epoch 40/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4732 - accuracy: 0.8611 - val_loss: 0.4972 - val_accuracy: 0.7368
# Epoch 41/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4631 - accuracy: 0.8611 - val_loss: 0.4876 - val_accuracy: 0.7368
# Epoch 42/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4536 - accuracy: 0.8611 - val_loss: 0.4788 - val_accuracy: 0.7368
# Epoch 43/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4445 - accuracy: 0.8611 - val_loss: 0.4714 - val_accuracy: 0.7368
# Epoch 44/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4364 - accuracy: 0.8611 - val_loss: 0.4667 - val_accuracy: 0.7368
# Epoch 45/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4280 - accuracy: 0.8611 - val_loss: 0.4635 - val_accuracy: 0.7368
# Epoch 46/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4196 - accuracy: 0.8611 - val_loss: 0.4609 - val_accuracy: 0.7368
# Epoch 47/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4119 - accuracy: 0.8611 - val_loss: 0.4581 - val_accuracy: 0.7368
# Epoch 48/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4039 - accuracy: 0.8611 - val_loss: 0.4545 - val_accuracy: 0.7368
# Epoch 49/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3966 - accuracy: 0.8611 - val_loss: 0.4515 - val_accuracy: 0.7368
# Epoch 50/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3896 - accuracy: 0.8611 - val_loss: 0.4476 - val_accuracy: 0.7368
# Epoch 51/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3827 - accuracy: 0.8611 - val_loss: 0.4425 - val_accuracy: 0.7368
# Epoch 52/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3757 - accuracy: 0.8611 - val_loss: 0.4374 - val_accuracy: 0.7368
# Epoch 53/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3695 - accuracy: 0.8611 - val_loss: 0.4323 - val_accuracy: 0.7368
# Epoch 54/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3633 - accuracy: 0.8611 - val_loss: 0.4258 - val_accuracy: 0.7368
# Epoch 55/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3572 - accuracy: 0.8611 - val_loss: 0.4167 - val_accuracy: 0.7368
# Epoch 56/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3510 - accuracy: 0.8611 - val_loss: 0.4044 - val_accuracy: 0.7368
# Epoch 57/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3452 - accuracy: 0.8611 - val_loss: 0.3927 - val_accuracy: 0.7368
# Epoch 58/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3394 - accuracy: 0.8611 - val_loss: 0.3834 - val_accuracy: 0.7368
# Epoch 59/80
# 2/2 [==============================] - 0s 168ms/step - loss: 0.3339 - accuracy: 0.8611 - val_loss: 0.3767 - val_accuracy: 0.7368
# Epoch 60/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3282 - accuracy: 0.8611 - val_loss: 0.3723 - val_accuracy: 0.7368
# Epoch 61/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3227 - accuracy: 0.8611 - val_loss: 0.3680 - val_accuracy: 0.7368
# Epoch 62/80
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3172 - accuracy: 0.8611 - val_loss: 0.3630 - val_accuracy: 0.7368
# Epoch 63/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3118 - accuracy: 0.8611 - val_loss: 0.3586 - val_accuracy: 0.7895
# Epoch 64/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3068 - accuracy: 0.8611 - val_loss: 0.3551 - val_accuracy: 0.7895
# Epoch 65/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3017 - accuracy: 0.8611 - val_loss: 0.3520 - val_accuracy: 0.7895
# Epoch 66/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2970 - accuracy: 0.8750 - val_loss: 0.3501 - val_accuracy: 0.7895
# Epoch 67/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2924 - accuracy: 0.8750 - val_loss: 0.3492 - val_accuracy: 0.7895
# Epoch 68/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2885 - accuracy: 0.8750 - val_loss: 0.3472 - val_accuracy: 0.7895
# Epoch 69/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2843 - accuracy: 0.8750 - val_loss: 0.3444 - val_accuracy: 0.7895
# Epoch 70/80
# 2/2 [==============================] - 0s 46ms/step - loss: 0.2803 - accuracy: 0.8750 - val_loss: 0.3409 - val_accuracy: 0.7895
# Epoch 71/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2763 - accuracy: 0.8750 - val_loss: 0.3369 - val_accuracy: 0.7895
# Epoch 72/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2723 - accuracy: 0.8750 - val_loss: 0.3339 - val_accuracy: 0.7895
# Epoch 73/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2688 - accuracy: 0.8750 - val_loss: 0.3296 - val_accuracy: 0.7895
# Epoch 74/80
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2647 - accuracy: 0.8750 - val_loss: 0.3228 - val_accuracy: 0.7895
# Epoch 75/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2600 - accuracy: 0.8750 - val_loss: 0.3144 - val_accuracy: 0.7895
# Epoch 76/80
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2549 - accuracy: 0.8750 - val_loss: 0.3068 - val_accuracy: 0.7895
# Epoch 77/80
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2497 - accuracy: 0.8750 - val_loss: 0.2985 - val_accuracy: 0.7895
# Epoch 78/80
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2447 - accuracy: 0.8750 - val_loss: 0.2891 - val_accuracy: 0.7895
# Epoch 79/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2392 - accuracy: 0.8750 - val_loss: 0.2793 - val_accuracy: 0.7895
# Epoch 80/80
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2345 - accuracy: 0.8750 - val_loss: 0.2692 - val_accuracy: 0.7895

# %%
scores_trainig = model.evaluate(X_train, y_train, verbose=1)
print("Training Loss: %f%%" % (scores_trainig[0]))
print("Training Accuracy: %.2f%%" % (scores_trainig[1]*100))
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2301 - accuracy: 0.8750
# Training Loss: 0.230108%
# Training Accuracy: 87.50%

# %%
scores_test = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss: %f%%" % (scores_test[0]))
print("Test Accuracy: %.2f%%" % (scores_test[1]*100))
# Out:
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2692 - accuracy: 0.7895
# Test Loss: 0.269240%
# Test Accuracy: 78.95%

# %%
import numpy as np

def predict_sequence(model,response):
    
    response= remove_stowords(response)
    #print(corps)
# Convert texts to sequences of integers
    sequences = tokenizer.texts_to_sequences(response)

# Pad sequences to ensure uniform length

    sequences = pad_sequences(sequences, max_sequence_length)
   
    
    #print(sequences)
    # Reshape the input for model prediction
    #input_data = np.array([sequences])
    
    #print(input_data)
    # Make predictions
    predicted_probs = model.predict(sequences)
    predicted_value= np.argmax(predicted_probs, axis=1)
    
    #print(predicted_classes)
   
    return predicted_value[0]

# %%
test=['بلال بن رباح الحبشي']

# %%
predict_sequence(model,test)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 2

# %%
from keras.models import load_model

# Assuming 'model' is your Keras model
model.save('model15.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
